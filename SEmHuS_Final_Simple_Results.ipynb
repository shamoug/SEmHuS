# %% [markdown]
# # 1. Initialisation

# %% [markdown]
# ## 1.1. File System

# %%
from google.colab import drive
drive.mount("/content/drive")

! chmod -R 777 'drive/My Drive/Otago/F. The Thesis/Source Code'

% cd 'drive/My Drive/Otago/F. The Thesis/Source Code'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# chmod: cannot access 'drive/My Drive/Otago/F. The Thesis/Source Code': No such file or directory
# [Errno 2] No such file or directory: 'drive/My Drive/Otago/F. The Thesis/Source Code'
# /content/drive/My Drive/Otago/F. The Thesis/Source Code

# %% [markdown]
# ## 1.2. Importing Libraries

# %%
# !pip install 'h5py==2.10.0' --force-reinstall
# Out:
# Collecting h5py==2.10.0
#   Using cached h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
# Collecting numpy>=1.7
#   Using cached numpy-1.21.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
# Collecting six
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: six, numpy, h5py
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.2
#     Uninstalling numpy-1.21.2:
#       Successfully uninstalled numpy-1.21.2
#   Attempting uninstall: h5py
#     Found existing installation: h5py 2.10.0
#     Uninstalling h5py-2.10.0:
#       Successfully uninstalled h5py-2.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lucid 0.3.10 requires umap-learn, which is not installed.
# tensorflow 1.15.2 requires gast==0.2.2, but you have gast 0.4.0 which is incompatible.
# lucid 0.3.10 requires numpy<=1.19, but you have numpy 1.21.2 which is incompatible.
# kapre 0.3.5 requires tensorflow>=2.0.0, but you have tensorflow 1.15.2 which is incompatible.
# google-colab 1.0.0 requires six~=1.15.0, but you have six 1.16.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed h5py-2.10.0 numpy-1.21.2 six-1.16.0

# %%
import pandas as pd
import pandas_profiling
from pandas_profiling import ProfileReport

import time
import re
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
import nltk
import csv
import ast
import pickle
import itertools
import random
from scipy.spatial import distance

# %%
# %tensorflow_version 1.x
import tensorflow as tf
from keras import Model
from keras.backend.tensorflow_backend import set_session
import sklearn.metrics
from keras.preprocessing.sequence import pad_sequences
import keras.backend as K
from keras.losses import mse

# %%
from keras.models import load_model

# %%
import gensim
from gensim.models import Word2Vec
from gensim.utils import simple_preprocess
from gensim.models.keyedvectors import KeyedVectors

# %%
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
sys.path.insert(0, './Libraries')
import preprocess

# %% [markdown]
# ## 1.3. GPU Initialisation

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
config.log_device_placement = True  # to log device placement (on which device the operation ran)
sess = tf.Session(config=config)
set_session(sess)  # set this TensorFlow session as the default session for Keras
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device

# %% [markdown]
# ## 1.4. Global Variables

# %%
model_name = 'RIVEC300_SMALL_'
max_word = 3500

# %% [markdown]
# ## 1.5. Model Reloading

# %%
def custom_loss_func(first_pos, second_pos):
    def custom_loss(y_true, y_pred):
        first_idx = K.argmax(K.abs(first_pos), axis = -1)
        second_idx = K.argmax(K.abs(second_pos), axis = -1)
        
        first_max = tf.gather(first_pos, first_idx, axis = 1)
        second_max = tf.gather(second_pos, second_idx, axis = 1)

        first_second = K.mean(mse(first_max, second_max)) * 0.1
        first_first = K.binary_crossentropy(y_true, y_pred)

        return mse(first_second, first_first)
    custom_loss.__name__ = 'custom_loss'
    return custom_loss

# %%
modelInputFile = f'./Model/{model_name}SEmHus_Word_Embedding_Model.h5'
model = load_model(modelInputFile)

# %% [markdown]
# ## 1.6. Tokenizers Reloading

# %%
with open(f'./Tokenizer/{model_name}text.pickle', 'rb') as handle:
    texts_tok = pickle.load(handle)

with open(f'./Tokenizer/{model_name}actor.pickle', 'rb') as handle:
    labActor_tok = pickle.load(handle)

with open(f'./Tokenizer/{model_name}agency.pickle', 'rb') as handle:
    labAgency_tok = pickle.load(handle)

with open(f'./Tokenizer/{model_name}sector.pickle', 'rb') as handle:
    labSector_tok = pickle.load(handle)

with open(f'./Tokenizer/{model_name}place.pickle', 'rb') as handle:
    labPlace_tok = pickle.load(handle)

with open(f'./Tokenizer/{model_name}year.pickle', 'rb') as handle:
    labYear_tok = pickle.load(handle)

with open(f'./Tokenizer/{model_name}month.pickle', 'rb') as handle:
    labMonth_tok = pickle.load(handle)

with open(f'./Tokenizer/{model_name}reason.pickle', 'rb') as handle:
    labReason_tok = pickle.load(handle)

with open(f'./Tokenizer/{model_name}goal.pickle', 'rb') as handle:
    labGoal_tok = pickle.load(handle)

# %% [markdown]
# # 2. Data Preparation

# %%
def clean_alpha(text):
    text = ' '.join([w for w in str(text).split() if w.isalpha()])
    return text

# %% [markdown]
# ## 2.1. Input and Output

# %%
normInputFile = f'./Inputs/{model_name}SEmHus_Enriched_Normalised_Dataset_Test.csv'
normDF = pd.read_csv(normInputFile)

# %%
normDF = normDF.loc[(normDF['country_name'] != "['World']") & (normDF['disaster_type'] != "['Other']") & (normDF['source_type'] != "['Media']")]

# %%
docs = normDF['text'].tolist()
labActor = [eval(v) for v in normDF['source_name'].tolist()]
labAgency = [eval(v) for v in normDF['source_type'].tolist()]
labSector = [eval(v) for v in normDF['theme'].tolist()]
labPlace = [eval(v) for v in normDF['country_name'].tolist()]
labYear = [eval(v) for v in normDF['year_created'].tolist()]
labMonth = [eval(v) for v in normDF['month_created'].tolist()]
labReason = [eval(v) for v in normDF['disaster_type'].tolist()]
labGoal = [eval(v) for v in normDF['development_goal'].tolist()]

# %%
docs = [' '.join(str(d).lower().split()[:max_word]) for d in docs]

# %%
padding_len = model.layers[0].get_output_at(0).get_shape().as_list()[1]

# %% [markdown]
# ## 2.2. Import Dictionaries

# %%
list_encoded_text = f'./Dictionary/{model_name}list_encoded_text.csv'
word_embed_dict = f'./Dictionary/{model_name}word_embed_dict.csv'

# %%
with open(list_encoded_text) as csv_file:
    reader = csv.reader(csv_file)
    dictText = {rows[0]:rows[1] for rows in reader}

with open(word_embed_dict) as csv_file:
    reader = csv.reader(csv_file)
    dictEmbed = {rows[0]:np.array(eval(rows[1])) for rows in reader}

# %% [markdown]
# Reversed Dictionaries

# %%
encoded_text = texts_tok.texts_to_sequences(docs)
encoded_text = pad_sequences(encoded_text, maxlen=padding_len, padding='post', truncating='post')

encoded_actor = labActor_tok.transform(labActor)
encoded_agency = labAgency_tok.transform(labAgency)
encoded_sector = labSector_tok.transform(labSector)
encoded_place = labPlace_tok.transform(labPlace)
encoded_year = labYear_tok.transform(labYear)
encoded_month = labMonth_tok.transform(labMonth)
encoded_reason = labReason_tok.transform(labReason)
encoded_goal = labGoal_tok.transform(labGoal)
encoded_stat = np.array([[1]] * len(encoded_text))

# %%
print(model.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 100)          0
# __________________________________________________________________________________________________
# inpWeight (Embedding)           (None, 100, 300)     3000000     input_1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 30000)        0           inpWeight[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 300)          9000300     flatten_1[0][0]
# __________________________________________________________________________________________________
# outActor (Dense)                (None, 1117)         336217      dense_1[0][0]
# __________________________________________________________________________________________________
# outAgency (Dense)               (None, 7)            2107        dense_1[0][0]
# __________________________________________________________________________________________________
# outSector (Dense)               (None, 19)           5719        dense_1[0][0]
# __________________________________________________________________________________________________
# outPlace (Dense)                (None, 203)          61103       dense_1[0][0]
# __________________________________________________________________________________________________
# outYear (Dense)                 (None, 22)           6622        dense_1[0][0]
# __________________________________________________________________________________________________
# outMonth (Dense)                (None, 12)           3612        dense_1[0][0]
# __________________________________________________________________________________________________
# outReason (Dense)               (None, 21)           6321        dense_1[0][0]
# __________________________________________________________________________________________________
# outGoal (Dense)                 (None, 16)           4816        dense_1[0][0]
# __________________________________________________________________________________________________
# outStat (Dense)                 (None, 1)            301         dense_1[0][0]
# ==================================================================================================
# Total params: 12,427,118
# Trainable params: 12,427,118
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# # 3. Class Embedding

# %% [markdown]
# ## 3.1. Semantic Similarity Setup

# %%
num_word = 5

# %%
agency_weight = model.get_layer('outAgency').get_weights()[0]
agency_transpose = np.asarray(np.transpose(agency_weight))
agency_embed = {w: agency_transpose[idx] for idx, w in enumerate(labAgency_tok.classes_)}

actor_weight = model.get_layer('outActor').get_weights()[0]
actor_transpose = np.asarray(np.transpose(actor_weight))
actor_embed = {w: actor_transpose[idx] for idx, w in enumerate(labActor_tok.classes_)}

goal_weight = model.get_layer('outGoal').get_weights()[0]
goal_transpose = np.asarray(np.transpose(goal_weight))
goal_embed = {w: goal_transpose[idx] for idx, w in enumerate(labGoal_tok.classes_)}

sector_weight = model.get_layer('outSector').get_weights()[0]
sector_transpose = np.asarray(np.transpose(sector_weight))
sector_embed = {w: sector_transpose[idx] for idx, w in enumerate(labSector_tok.classes_)}

place_weight = model.get_layer('outPlace').get_weights()[0]
place_transpose = np.asarray(np.transpose(place_weight))
place_embed = {w: place_transpose[idx] for idx, w in enumerate(labPlace_tok.classes_)}

year_weight = model.get_layer('outYear').get_weights()[0]
year_transpose = np.asarray(np.transpose(year_weight))
year_embed = {w: year_transpose[idx] for idx, w in enumerate(labYear_tok.classes_)}

month_weight = model.get_layer('outMonth').get_weights()[0]
month_transpose = np.asarray(np.transpose(month_weight))
month_embed = {w: month_transpose[idx] for idx, w in enumerate(labMonth_tok.classes_)}

reason_weight = model.get_layer('outReason').get_weights()[0]
reason_transpose = np.asarray(np.transpose(reason_weight))
reason_embed = {w: reason_transpose[idx] for idx, w in enumerate(labReason_tok.classes_)}

# %%
def nearest_class(first, second, third):
    if first == 'agency': class_list = agency_embed.items()
    if first == 'actor': class_list = actor_embed.items()
    if first == 'goal': class_list = goal_embed.items()
    if first == 'sector': class_list = sector_embed.items()
    if first == 'place': class_list = place_embed.items()
    if first == 'year': class_list = year_embed.items()
    if first == 'month': class_list = month_embed.items()
    if first == 'reason': class_list = reason_embed.items()

    if second == 'agency': vec1 = agency_embed[third]
    if second == 'actor': vec1 = actor_embed[third]
    if second == 'goal': vec1 = goal_embed[third]
    if second == 'sector': vec1 = sector_embed[third]
    if second == 'place': vec1 = place_embed[third]
    if second == 'year': vec1 = year_embed[third]
    if second == 'month': vec1 = month_embed[third]
    if second == 'reason': vec1 = reason_embed[third]

    dist = []
    for word, vec2 in class_list:
        #dist.append((np.linalg.norm(vec1 - vec2), word))
        dist.append((round(distance.cosine(vec1, vec2), 4), word))
    dist.sort()
    dist = dist[:num_word]
    return dist

# %% [markdown]
# ## 3.2. Semantic Similarity Measure

# %%
var1, var2 = 'reason', 'place'

if var2 == 'agency': rand_class = labAgency_tok.classes_[random.randint(0, len(labAgency_tok.classes_)-1)]
if var2 == 'actor': rand_class = labActor_tok.classes_[random.randint(0, len(labActor_tok.classes_)-1)]
if var2 == 'goal': rand_class = labGoal_tok.classes_[random.randint(0, len(labGoal_tok.classes_)-1)]
if var2 == 'sector': rand_class = labSector_tok.classes_[random.randint(0, len(labSector_tok.classes_)-1)]
if var2 == 'place': rand_class = labPlace_tok.classes_[random.randint(0, len(labPlace_tok.classes_)-1)]
if var2 == 'year': rand_class = labYear_tok.classes_[random.randint(0, len(labYear_tok.classes_)-1)]
if var2 == 'month': rand_class = labMonth_tok.classes_[random.randint(0, len(labMonth_tok.classes_)-1)]
if var2 == 'reason': rand_class = labReason_tok.classes_[random.randint(0, len(labReason_tok.classes_)-1)]

# rand_class = 'Zambia'

print(f'Nearest {var1} to this {var2} [{rand_class}] is:\n')

# nearest_class(var1, var2, rand_class)

nearest_text = ''

ents = nearest_class(var1, var2, rand_class)

for ent in ents:
    nearest_text += f'{ent[1]} ({ent[0]}); '

# print(nearest_text)
nearest_text
# Out:
# Nearest reason to this place [Honduras] is:
# 'Mud Slide (0.7782); Drought (0.8335); Tropical Cyclone (0.8576); Extratropical Cyclone (0.8894); Epidemic (0.9011); '

# %% [markdown]
# ## 3.3. Vector Space Export

# %%
cols = ['Class', 'Entity', 'Vector']
rows = []

for key, value in agency_embed.items():
    rows.append(['Agency', key, list(value)])

for key, value in actor_embed.items():
    rows.append(['Actor', key, list(value)])

for key, value in goal_embed.items():
    rows.append(['SDG', key, list(value)])

for key, value in sector_embed.items():
    rows.append(['Sector', key, list(value)])

for key, value in place_embed.items():
    rows.append(['Place', key, list(value)])

for key, value in year_embed.items():
    rows.append(['Year', key, list(value)])

for key, value in month_embed.items():
    rows.append(['Month', key, list(value)])

for key, value in reason_embed.items():
    rows.append(['Reason', key, list(value)])

class_df = pd.DataFrame(data=rows, columns = cols)
class_df.to_csv(f'./Outputs/{model_name}Humanitarian_Class_Vector_Space.csv')

# %% [markdown]
# ## 3.4. Entity Distance Export

# %%
class_data = class_df.values.tolist()

# %%
def nearest_label(group, entity):
    vec1 = class_df.loc[class_df['Entity'] == entity]
    vec1 = vec1.iloc[0]['Vector']
    dist = []
    for cls, ent, vec2 in class_data:
        if group == '*':
            dist.append((round(distance.cosine(vec1, vec2), 4), ent, cls))
        if group == cls:
            dist.append((round(distance.cosine(vec1, vec2), 4), ent, cls))
    dist.sort()
    dist = dist[:10]
    return dist

# %%
rand_num = random.randint(0, len(class_df)-1)

rand_class = class_df.iloc[rand_num]['Entity']
near_class = class_df.iloc[rand_num]['Class']

rand_class = 'Cambodia'

# near_group = '*'
near_group = 'Sector'

print(f'Nearest {near_group} to [{rand_class}] is:\n')
nearest_label(near_group, rand_class)
# Out:
# Nearest Sector to [Cambodia] is:
# [(0.9026, 'Water Sanitation Hygiene', 'Sector'),
#  (0.9112, 'HIV/Aids', 'Sector'),
#  (0.9301, 'Food and Nutrition', 'Sector'),
#  (0.9317, 'Disaster Management', 'Sector'),
#  (0.9377, 'Climate Change and Environment', 'Sector'),
#  (0.9409, 'Agriculture', 'Sector'),
#  (0.9528, 'Gender', 'Sector'),
#  (0.9645, 'Mine Action', 'Sector'),
#  (0.9657, 'Humanitarian Financing', 'Sector'),
#  (0.9679, 'Contributions', 'Sector')]

# %% [markdown]
# # 4. Model Evaluation

# %%
print(model.metrics_names)
# Out:
# ['loss', 'outActor_loss', 'outAgency_loss', 'outSector_loss', 'outPlace_loss', 'outYear_loss', 'outMonth_loss', 'outReason_loss', 'outGoal_loss', 'outStat_loss', 'outActor_categorical_accuracy', 'outAgency_categorical_accuracy', 'outSector_categorical_accuracy', 'outPlace_categorical_accuracy', 'outYear_categorical_accuracy', 'outMonth_categorical_accuracy', 'outReason_categorical_accuracy', 'outGoal_categorical_accuracy', 'outStat_categorical_accuracy']

# %%
loss, _, _, _, _, _, _, _, _, _, accActor, accAgency, accSector, accPlace, accYear, accMonth, accReason, accGoal, accStat = model.evaluate(
    [encoded_text],
    [encoded_actor, encoded_agency, encoded_sector, encoded_place,
     encoded_year, encoded_month, encoded_reason, encoded_goal, encoded_stat], verbose=0)

# %%
print('Overall Loss is: %f' % (loss))
print('Actor Accuracy: %f' % (accActor*100))
print('Agency Accuracy: %f' % (accAgency*100))
print('Sector Accuracy: %f' % (accSector*100))
print('Place Accuracy: %f' % (accPlace*100))
print('Year Accuracy: %f' % (accYear*100))
print('Month Accuracy: %f' % (accMonth*100))
print('Reason Accuracy: %f' % (accReason*100))
print('SDG Accuracy: %f' % (accGoal*100))
# Out:
# Overall Loss is: 0.643880
# Actor Accuracy: 70.984846
# Agency Accuracy: 92.348486
# Sector Accuracy: 56.818181
# Place Accuracy: 86.609846
# Year Accuracy: 81.287879
# Month Accuracy: 68.806821
# Reason Accuracy: 71.268940
# SDG Accuracy: 73.295456

# %% [markdown]
# ## 4.2. Categorical Evaluation

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
actor_pred, agency_pred, sector_pred, place_pred, year_pred, month_pred, reason_pred, goal_pred, stat_pred = model.predict(encoded_text, verbose=0)

actor_pred = np.where(actor_pred>=0.5, 1, 0)
agency_pred = np.where(agency_pred>=0.5, 1, 0)
sector_pred = np.where(sector_pred>=0.5, 1, 0)
place_pred = np.where(place_pred>=0.5, 1, 0)
year_pred = np.where(year_pred>=0.5, 1, 0)
month_pred = np.where(month_pred>=0.5, 1, 0)
reason_pred = np.where(reason_pred>=0.5, 1, 0)
goal_pred = np.where(goal_pred>=0.5, 1, 0)

# %%
actor_label = [c for c in labActor_tok.classes_ if c in labActor]

# %%
# len(set(encoded_actor))

# %%
def hamming_score(y_true, y_pred, normalize=True, sample_weight=None):
    acc_list = []
    for i in range(y_true.shape[0]):
        set_true = set( np.where(y_true[i])[0] )
        set_pred = set( np.where(y_pred[i])[0] )
        tmp_a = None
        if len(set_true) == 0 and len(set_pred) == 0:
            tmp_a = 1
        else:
            tmp_a = len(set_true.intersection(set_pred))/\
                    float( len(set_true.union(set_pred)) )
        acc_list.append(tmp_a)
    return np.mean(acc_list)

# %% [markdown]
# ### 2.4.1. Actor Evaluation

# %%
actor_report = classification_report(encoded_actor, actor_pred, target_names=labActor_tok.classes_, digits=6, zero_division=False, output_dict=True)

report = []

for k, v in actor_report.items():
    p, r, f, s = v.values()
    report.append([k, p, r, f, s])
report

exportDF = pd.DataFrame(report, columns = ['Class', 'Precision', 'Recall', 'F1', 'Support'])
exportDF.to_excel('./Results/Actor_Score_Matrix.xlsx')

# %%
print('Hamming score: {0}'.format(hamming_score(encoded_actor, actor_pred)))
print('Hamming loss: {0}'.format(sklearn.metrics.hamming_loss(encoded_actor, actor_pred)))
print('Subset accuracy: {0}'.format(sklearn.metrics.accuracy_score(encoded_actor, actor_pred, normalize=True, sample_weight=None)))
# Out:
# Hamming score: 0.6691130050505051
# Hamming loss: 0.0004671265022652668
# Subset accuracy: 0.6640151515151516

# %%
tot_score = []

for idx, sub in enumerate(labActor_tok.classes_):

    subDF = normDF.loc[normDF['source_name'].str.contains(sub)]

    cnt_report = len(subDF)
    if cnt_report <=0 : continue

    inpText = subDF['text'].tolist()
    inpText = [' '.join(str(d).lower().split()[:max_word]) for d in inpText]
    inpText = texts_tok.texts_to_sequences(inpText)
    inpText = pad_sequences(inpText, maxlen=padding_len, padding='post', truncating='post')

    outActor = [[sub]] * cnt_report
    
    outActor = labActor_tok.transform(outActor)

    preActor, preAgency, preSector, prePlace, preYear, preMonth, preReason, preGoal, preStat = model.predict(inpText, verbose=0)

    preActor = np.where(preActor>=np.sort(preActor[0])[-1], 1, 0)

    acc_report = sklearn.metrics.accuracy_score(outActor, preActor, normalize=True)
    prc_report = sklearn.metrics.precision_score(outActor, preActor, average='micro')
    rcl_report = sklearn.metrics.recall_score(outActor, preActor,  average='micro')
    fsc_report = sklearn.metrics.f1_score(outActor, preActor,  average='micro')
    avg_report = (acc_report + prc_report + rcl_report + fsc_report) / 4

    tn, fp, fn, tp = sklearn.metrics.confusion_matrix(outActor.flatten(), preActor.flatten()).ravel()
    
    tot_score.append([sub, tn, fp, fn, tp, acc_report, prc_report, rcl_report, fsc_report, avg_report, cnt_report, outActor.argmax(axis=1).tolist(), preActor.argmax(axis=1).tolist()])

actor_score = pd.DataFrame(tot_score, columns = ['Actor', 'TN', 'FP', 'FN', 'TP', 'Accuracy', 'Precision', 'Recall', 'F1', 'Score', 'Support', 'True_Y', 'Pred_Y']) 
actor_score.to_excel('./Results/Actor_Score_Matrix.xlsx')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)

# %% [markdown]
# ### 2.4.2. Agency Evaluation

# %%
agency_report = classification_report(encoded_agency, agency_pred, target_names=labAgency_tok.classes_, digits=6, zero_division=False, output_dict=True)
print(agency_report)
# Out:
# {'Academic and Research Institution': {'precision': 0.9761904761904762, 'recall': 0.6612903225806451, 'f1-score': 0.7884615384615384, 'support': 62}, 'Government': {'precision': 0.9510268562401264, 'recall': 0.8905325443786982, 'f1-score': 0.9197860962566845, 'support': 1352}, 'International Organization': {'precision': 0.9264870931537598, 'recall': 0.938601478112564, 'f1-score': 0.9325049421067495, 'support': 1759}, 'Media': {'precision': 0.14516129032258066, 'recall': 0.6428571428571429, 'f1-score': 0.2368421052631579, 'support': 14}, 'Non-governmental Organization': {'precision': 0.9573333333333334, 'recall': 0.9270497094899935, 'f1-score': 0.9419481797310594, 'support': 1549}, 'Other': {'precision': 0.9565217391304348, 'recall': 0.7096774193548387, 'f1-score': 0.8148148148148149, 'support': 31}, 'Red Cross/Red Crescent Movement': {'precision': 0.9799196787148594, 'recall': 0.8888888888888888, 'f1-score': 0.9321872015281757, 'support': 549}, 'micro avg': {'precision': 0.9377537212449256, 'recall': 0.912528216704289, 'f1-score': 0.9249690151587378, 'support': 5316}, 'macro avg': {'precision': 0.8418057810122244, 'recall': 0.8084139293803959, 'f1-score': 0.7952206968803115, 'support': 5316}, 'weighted avg': {'precision': 0.9459316374987348, 'recall': 0.912528216704289, 'f1-score': 0.9277906628037524, 'support': 5316}, 'samples avg': {'precision': 0.91875, 'recall': 0.915719696969697, 'f1-score': 0.9167297979797981, 'support': 5316}}

# %%
report = []

for k, v in agency_report.items():
    p, r, f, s = v.values()
    report.append([k, p, r, f, s])
report

exportDF = pd.DataFrame(report, columns = ['Class', 'Precision', 'Recall', 'F1', 'Support'])
exportDF.to_excel('./Results/Agency_Score_Matrix.xlsx')

# %%
print('Hamming score: {0}'.format(hamming_score(encoded_agency, agency_pred)))
print('Hamming loss: {0}'.format(sklearn.metrics.hamming_loss(encoded_agency, agency_pred))) 
print('Subset accuracy: {0}'.format(sklearn.metrics.accuracy_score(encoded_agency, agency_pred, normalize=True, sample_weight=None)))
# Out:
# Hamming score: 0.915719696969697
# Hamming loss: 0.021293290043290045
# Subset accuracy: 0.912689393939394

# %%
tot_score = []

for idx, sub in enumerate(labAgency_tok.classes_):

    subDF = normDF.loc[normDF['source_type'].str.contains(sub)]

    cnt_report = len(subDF)
    if cnt_report <=0 : continue

    inpText = subDF['text'].tolist()
    inpText = [' '.join(str(d).lower().split()[:max_word]) for d in inpText]
    inpText = texts_tok.texts_to_sequences(inpText)
    inpText = pad_sequences(inpText, maxlen=padding_len, padding='post', truncating='post')

    outAgency = [[sub]] * cnt_report
    outAgency = labAgency_tok.transform(outAgency)

    preActor, preAgency, preSector, prePlace, preYear, preMonth, preReason, preGoal, preStat = model.predict(inpText, verbose=0)

    preAgency = np.where(preAgency>=0.5, 1, 0)

    acc_report = sklearn.metrics.accuracy_score(outAgency, preAgency, normalize=True)
    prc_report = sklearn.metrics.precision_score(outAgency, preAgency, average='micro')
    rcl_report = sklearn.metrics.recall_score(outAgency, preAgency, average='micro')
    fsc_report = sklearn.metrics.f1_score(outAgency, preAgency, average='micro')
    avg_report = (acc_report + prc_report + rcl_report + fsc_report) / 4
    
    tot_score.append([sub, acc_report, prc_report, rcl_report, fsc_report, cnt_report])

    print(sub, '\t', cnt_report, '\t', avg_report)

agency_score = pd.DataFrame(tot_score, columns = ['Agency', 'Accuracy', 'Precision', 'Recall', 'F1', 'Support']) 
agency_score.to_excel('./Results/Agency_Score_Matrix.xlsx')
# Out:
# Academic and Research Institution 	 62 	 0.6874096891353588
# Government 	 1352 	 0.8983390698664028
# International Organization 	 1759 	 0.9438690210877856
# Media 	 14 	 0.6428571428571429
# Non-governmental Organization 	 1549 	 0.9336614927721272
# Other 	 31 	 0.7184999118632116
# Red Cross/Red Crescent Movement 	 549 	 0.8994846814847788

# %% [markdown]
# ### 2.4.3. Sector Evaluation

# %%
sector_report = classification_report(encoded_sector, sector_pred, target_names=labSector_tok.classes_, digits=6, zero_division=False, output_dict=True)
print(sector_report)
# Out:
# {'Agriculture': {'precision': 0.9065420560747663, 'recall': 0.30842607313195547, 'f1-score': 0.46026097271648875, 'support': 629}, 'Climate Change and Environment': {'precision': 1.0, 'recall': 0.09302325581395349, 'f1-score': 0.1702127659574468, 'support': 43}, 'Contributions': {'precision': 0.911062906724512, 'recall': 0.42769857433808556, 'f1-score': 0.5821205821205822, 'support': 982}, 'Coordination': {'precision': 0.8209606986899564, 'recall': 0.29237947122861585, 'f1-score': 0.43119266055045874, 'support': 643}, 'Disaster Management': {'precision': 0.8620689655172413, 'recall': 0.3768844221105528, 'f1-score': 0.5244755244755245, 'support': 199}, 'Education': {'precision': 0.9213483146067416, 'recall': 0.2303370786516854, 'f1-score': 0.36853932584269666, 'support': 356}, 'Food and Nutrition': {'precision': 0.9275053304904051, 'recall': 0.27848911651728553, 'f1-score': 0.42836041358936483, 'support': 1562}, 'Gender': {'precision': 1.0, 'recall': 0.08333333333333333, 'f1-score': 0.15384615384615385, 'support': 12}, 'HIV/Aids': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 12}, 'Health': {'precision': 0.9593679458239278, 'recall': 0.45576407506702415, 'f1-score': 0.6179571065067249, 'support': 1865}, 'Humanitarian Financing': {'precision': 1.0, 'recall': 0.07692307692307693, 'f1-score': 0.14285714285714288, 'support': 13}, 'Logistics and Telecommunications': {'precision': 0.868421052631579, 'recall': 0.2391304347826087, 'f1-score': 0.37500000000000006, 'support': 138}, 'Mine Action': {'precision': 0.8888888888888888, 'recall': 0.5714285714285714, 'f1-score': 0.6956521739130435, 'support': 14}, 'Peacekeeping and Peacebuilding': {'precision': 0.8867924528301887, 'recall': 0.573170731707317, 'f1-score': 0.6962962962962962, 'support': 82}, 'Protection and Human Rights': {'precision': 0.9307692307692308, 'recall': 0.3009950248756219, 'f1-score': 0.45488721804511284, 'support': 402}, 'Recovery and Reconstruction': {'precision': 0.8767772511848341, 'recall': 0.3969957081545064, 'f1-score': 0.5465288035450516, 'support': 932}, 'Safety and Security': {'precision': 1.0, 'recall': 0.19047619047619047, 'f1-score': 0.32, 'support': 84}, 'Shelter and Non-Food Items': {'precision': 0.9081419624217119, 'recall': 0.2826510721247563, 'f1-score': 0.4311199207135778, 'support': 1539}, 'Water Sanitation Hygiene': {'precision': 0.9178743961352657, 'recall': 0.16183986371379896, 'f1-score': 0.27516292541636495, 'support': 1174}, 'micro avg': {'precision': 0.9143610013175231, 'recall': 0.32487594794494895, 'f1-score': 0.47941420281845815, 'support': 10681}, 'macro avg': {'precision': 0.8729748133046973, 'recall': 0.2810497933883653, 'f1-score': 0.4039194729680016, 'support': 10681}, 'weighted avg': {'precision': 0.9131951041288925, 'recall': 0.32487594794494895, 'f1-score': 0.4710060157843802, 'support': 10681}, 'samples avg': {'precision': 0.6571969696969697, 'recall': 0.4897220035856399, 'f1-score': 0.5375655499803227, 'support': 10681}}

# %%
report = []

for k, v in sector_report.items():
    p, r, f, s = v.values()
    report.append([k, p, r, f, s])
report

exportDF = pd.DataFrame(report, columns = ['Class', 'Precision', 'Recall', 'F1', 'Support'])
exportDF.to_excel('./Results/Sector_Score_Matrix.xlsx')

# %%
print('Hamming score: {0}'.format(hamming_score(encoded_sector, sector_pred)))
print('Hamming loss: {0}'.format(sklearn.metrics.hamming_loss(encoded_sector, sector_pred))) 
print('Subset accuracy: {0}'.format(sklearn.metrics.accuracy_score(encoded_sector, sector_pred, normalize=True, sample_weight=None)))
# Out:
# Hamming score: 0.4897220035856399
# Hamming loss: 0.07511961722488038
# Subset accuracy: 0.36363636363636365

# %%
tot_score = []

for idx, sub in enumerate(labSector_tok.classes_):

    subDF = normDF.loc[normDF['theme'].str.contains(sub)]

    cnt_report = len(subDF)
    if cnt_report <=0 : continue

    inpText = subDF['text'].tolist()
    inpText = [' '.join(str(d).lower().split()[:max_word]) for d in inpText]
    inpText = texts_tok.texts_to_sequences(inpText)
    inpText = pad_sequences(inpText, maxlen=padding_len, padding='post', truncating='post')

    outSector = [[sub]] * cnt_report
    outSector = labSector_tok.transform(outSector)

    preActor, preAgency, preSector, prePlace, preYear, preMonth, preReason, preGoal, preStat = model.predict(inpText, verbose=0)

    preSector = np.where(preSector>=0.5, 1, 0)

    acc_report = sklearn.metrics.accuracy_score(outSector, preSector, normalize=True)
    prc_report = sklearn.metrics.precision_score(outSector, preSector, average='micro')
    rcl_report = sklearn.metrics.recall_score(outSector, preSector, average='micro')
    fsc_report = sklearn.metrics.f1_score(outSector, preSector, average='micro')
    avg_report = (acc_report + prc_report + rcl_report + fsc_report) / 4

    tot_score.append([sub, acc_report, prc_report, rcl_report, fsc_report, cnt_report])

sector_score = pd.DataFrame(tot_score, columns = ['Sector', 'Accuracy', 'Precision', 'Recall', 'F1', 'Support']) 
sector_score.to_excel('./Results/Sector_Score_Matrix.xlsx')

# %% [markdown]
# ### 2.4.4. Place Evaluation

# %%
place_report = classification_report(encoded_place, place_pred, target_names=labPlace_tok.classes_, digits=6, zero_division=False, output_dict=True)
print(place_report)
# Out:
# {'Afghanistan': {'precision': 0.898876404494382, 'recall': 0.7619047619047619, 'f1-score': 0.8247422680412371, 'support': 105}, 'Albania': {'precision': 1.0, 'recall': 0.6, 'f1-score': 0.7499999999999999, 'support': 5}, 'Algeria': {'precision': 0.7727272727272727, 'recall': 0.8095238095238095, 'f1-score': 0.7906976744186046, 'support': 21}, 'American Samoa': {'precision': 0.75, 'recall': 0.9, 'f1-score': 0.8181818181818182, 'support': 10}, 'Angola': {'precision': 0.7857142857142857, 'recall': 0.7333333333333333, 'f1-score': 0.7586206896551724, 'support': 30}, 'Anguilla': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 0}, 'Antigua and Barbuda': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 0}, 'Argentina': {'precision': 1.0, 'recall': 0.6, 'f1-score': 0.7499999999999999, 'support': 5}, 'Armenia': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1}, 'Aruba (The Netherlands)': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 0}, 'Australia': {'precision': 1.0, 'recall': 0.5, 'f1-score': 0.6666666666666666, 'support': 10}, 'Austria': {'precision': 0.75, 'recall': 1.0, 'f1-score': 0.8571428571428571, 'support': 3}, 'Azerbaijan': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 0}, 'Bahamas': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 0}, 'Bahrain': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1}, 'Bangladesh': {'precision': 0.8555555555555555, 'recall': 0.7549019607843137, 'f1-score': 0.8020833333333333, 'support': 102}, 'Barbados': {'precision': 1.0, 'recall': 0.25, 'f1-score': 0.4, 'support': 4}, 'Belarus': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 0}, 'Belgium': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 0}, 'Belize': {'precision': 0.7777777777777778, 'recall': 0.5833333333333334, 'f1-score': 0.6666666666666666, 'support': 12}, 'Benin': {'precision': 0.6666666666666666, 'recall': 0.2857142857142857, 'f1-score': 0.4, 'support': 7}, 'Bermuda': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 0}, 'Bhutan': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 0}, 'Bolivia (Plurinational State of)': {'precision': 0.9545454545454546, 'recall': 0.75, 'f1-score': 0.84, 'support': 28}, 'Bosnia and Herzegovina': {'precision': 1.0, 'recall': 0.8076923076923077, 'f1-score': 0.8936170212765957, 'support': 26}, 'Botswana': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3}, 'Brazil': {'precision': 1.0, 'recall': 0.45454545454545453, 'f1-score': 0.625, 'support': 11}, 'British Virgin Islands': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 0}, 'Brunei Darussalam': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 0}, 'Bulgaria': {'precision': 1.0, 'recall': 0.5, 'f1-score': 0.6666666666666666, 'support': 4}, 'Burkina Faso': {'precision': 0.8421052631578947, 'recall': 0.6956521739130435, 'f1-score': 0.761904761904762, 'support': 46}, 'Burundi': {'precision': 1.0, 'recall': 0.42857142857142855, 'f1-score': 0.6, 'support': 7}, 'Cabo Verde': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 1}, 'Cambodia': {'precision': 1.0, 'recall': 0.9285714285714286, 'f1-score': 0.962962962962963, 'support': 14}, 'Cameroon': {'precision': 0.8125, 'recall': 0.7222222222222222, 'f1-score': 0.7647058823529411, 'support': 18}, 'Canada': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2}, 'Cayman Islands': {'precision': 0.6666666666666666, 'recall': 0.6666666666666666, 'f1-score': 0.6666666666666666, 'support': 3}, 'Central African Republic': {'precision': 1.0, 'recall': 0.4, 'f1-score': 0.5714285714285715, 'support': 10}, 'Chad': {'precision': 0.92, 'recall': 0.6216216216216216, 'f1-score': 0.7419354838709677, 'support': 37}, 'Chile': {'precision': 1.0, 'recall': 0.7142857142857143, 'f1-score': 0.8333333333333333, 'support': 14}, 'China': {'precision': 0.9761904761904762, 'recall': 0.9044117647058824, 'f1-score': 0.9389312977099237, ' ...

# %%
report = []

for k, v in place_report.items():
    p, r, f, s = v.values()
    report.append([k, p, r, f, s])
report

exportDF = pd.DataFrame(report, columns = ['Class', 'Precision', 'Recall', 'F1', 'Support'])
exportDF.to_excel('./Results/Place_Score_Matrix.xlsx')

# %%
print('Hamming score: {0}'.format(hamming_score(encoded_place, place_pred)))
print('Hamming loss: {0}'.format(sklearn.metrics.hamming_loss(encoded_place, place_pred))) 
print('Subset accuracy: {0}'.format(sklearn.metrics.accuracy_score(encoded_place, place_pred, normalize=True, sample_weight=None)))
# Out:
# Hamming score: 0.8426136363636364
# Hamming loss: 0.0011727496641289745
# Subset accuracy: 0.8426136363636364

# %%
tot_score = []

for idx, sub in enumerate(labPlace_tok.classes_):

    subDF = normDF.loc[normDF['country_name'].str.contains(sub)]

    cnt_report = len(subDF)
    if cnt_report <=0 : continue

    inpText = subDF['text'].tolist()
    inpText = [' '.join(str(d).lower().split()[:max_word]) for d in inpText]
    inpText = texts_tok.texts_to_sequences(inpText)
    inpText = pad_sequences(inpText, maxlen=padding_len, padding='post', truncating='post')

    outPlace = [[sub]] * cnt_report
    outPlace = labPlace_tok.transform(outPlace)

    preActor, preAgency, preSector, prePlace, preYear, preMonth, preReason, preGoal, preStat = model.predict(inpText, verbose=0)

    prePlace = np.where(prePlace>=0.5, 1, 0)

    acc_report = sklearn.metrics.accuracy_score(outPlace, prePlace, normalize=True)
    prc_report = sklearn.metrics.precision_score(outPlace, prePlace, average='micro')
    rcl_report = sklearn.metrics.recall_score(outPlace, prePlace, average='micro')
    fsc_report = sklearn.metrics.f1_score(outPlace, prePlace, average='micro')
    avg_report = (acc_report + prc_report + rcl_report + fsc_report) / 4

    tot_score.append([sub, acc_report, prc_report, rcl_report, fsc_report, cnt_report])

place_score = pd.DataFrame(tot_score, columns = ['Place', 'Accuracy', 'Precision', 'Recall', 'F1', 'Support']) 
place_score.to_excel('./Results/Place_Score_Matrix.xlsx')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### 2.4.5. Year Evaluation

# %%
year_report = classification_report(encoded_year, year_pred, target_names=labYear_tok.classes_, digits=6, zero_division=False, output_dict=True)
print(year_report)
# Out:
# {'1995': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 0}, '1996': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 0}, '1997': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 0}, '1998': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 2}, '1999': {'precision': 0.9285714285714286, 'recall': 0.7647058823529411, 'f1-score': 0.8387096774193549, 'support': 17}, '2000': {'precision': 0.72, 'recall': 0.6666666666666666, 'f1-score': 0.6923076923076923, 'support': 27}, '2001': {'precision': 0.9423076923076923, 'recall': 0.7313432835820896, 'f1-score': 0.8235294117647058, 'support': 67}, '2002': {'precision': 0.9047619047619048, 'recall': 0.7916666666666666, 'f1-score': 0.8444444444444444, 'support': 24}, '2003': {'precision': 0.8953488372093024, 'recall': 0.7777777777777778, 'f1-score': 0.8324324324324325, 'support': 99}, '2004': {'precision': 0.875, 'recall': 0.7962085308056872, 'f1-score': 0.8337468982630273, 'support': 211}, '2005': {'precision': 0.871499176276771, 'recall': 0.8643790849673203, 'f1-score': 0.8679245283018868, 'support': 612}, '2006': {'precision': 0.8341968911917098, 'recall': 0.6851063829787234, 'f1-score': 0.7523364485981308, 'support': 235}, '2007': {'precision': 0.8051948051948052, 'recall': 0.7560975609756098, 'f1-score': 0.7798742138364779, 'support': 246}, '2008': {'precision': 0.8646288209606987, 'recall': 0.7122302158273381, 'f1-score': 0.7810650887573966, 'support': 278}, '2009': {'precision': 0.9, 'recall': 0.7008196721311475, 'f1-score': 0.7880184331797234, 'support': 244}, '2010': {'precision': 0.8485804416403786, 'recall': 0.7577464788732394, 'f1-score': 0.8005952380952381, 'support': 355}, '2011': {'precision': 0.8205128205128205, 'recall': 0.7058823529411765, 'f1-score': 0.7588932806324111, 'support': 408}, '2012': {'precision': 0.781038374717833, 'recall': 0.7361702127659574, 'f1-score': 0.7579408543263965, 'support': 470}, '2013': {'precision': 0.8733031674208145, 'recall': 0.8201133144475921, 'f1-score': 0.845872899926954, 'support': 706}, '2014': {'precision': 0.8765243902439024, 'recall': 0.8765243902439024, 'f1-score': 0.8765243902439024, 'support': 656}, '2015': {'precision': 0.8819599109131403, 'recall': 0.7967806841046278, 'f1-score': 0.8372093023255814, 'support': 497}, '2016': {'precision': 0.8818181818181818, 'recall': 0.7698412698412699, 'f1-score': 0.8220338983050849, 'support': 126}, 'micro avg': {'precision': 0.857113273969766, 'recall': 0.7839015151515152, 'f1-score': 0.8188742704520725, 'support': 5280}, 'macro avg': {'precision': 0.7047839474427903, 'recall': 0.6231845649068061, 'f1-score': 0.6606117787800382, 'support': 5280}, 'weighted avg': {'precision': 0.8569841243154795, 'recall': 0.7839015151515152, 'f1-score': 0.8177808660736875, 'support': 5280}, 'samples avg': {'precision': 0.7839015151515152, 'recall': 0.7839015151515152, 'f1-score': 0.7839015151515152, 'support': 5280}}

# %%
report = []

for k, v in year_report.items():
    p, r, f, s = v.values()
    report.append([k, p, r, f, s])
report

exportDF = pd.DataFrame(report, columns = ['Class', 'Precision', 'Recall', 'F1', 'Support'])
exportDF.to_excel('./Results/Year_Score_Matrix.xlsx')

# %%
print('Hamming score: {0}'.format(hamming_score(encoded_year, year_pred)))
print('Hamming loss: {0}'.format(sklearn.metrics.hamming_loss(encoded_year, year_pred))) 
print('Subset accuracy: {0}'.format(sklearn.metrics.accuracy_score(encoded_year, year_pred, normalize=True, sample_weight=None)))
# Out:
# Hamming score: 0.7839015151515152
# Hamming loss: 0.015762741046831955
# Subset accuracy: 0.7839015151515152

# %%
tot_score = []

for idx, sub in enumerate(labYear_tok.classes_):

    subDF = normDF.loc[normDF['year_created'].str.contains(sub)]

    cnt_report = len(subDF)
    if cnt_report <=0 : continue

    inpText = subDF['text'].tolist()
    inpText = [' '.join(str(d).lower().split()[:max_word]) for d in inpText]
    inpText = texts_tok.texts_to_sequences(inpText)
    inpText = pad_sequences(inpText, maxlen=padding_len, padding='post', truncating='post')

    outYear = [[sub]] * cnt_report
    outYear = labYear_tok.transform(outYear)

    preActor, preAgency, preSector, prePlace, preYear, preMonth, preReason, preGoal, preStat = model.predict(inpText, verbose=0)

    preYear = np.where(preYear>=0.5, 1, 0)

    acc_report = sklearn.metrics.accuracy_score(outYear, preYear, normalize=True)
    prc_report = sklearn.metrics.precision_score(outYear, preYear, average='micro')
    rcl_report = sklearn.metrics.recall_score(outYear, preYear, average='micro')
    fsc_report = sklearn.metrics.f1_score(outYear, preYear, average='micro')
    avg_report = (acc_report + prc_report + rcl_report + fsc_report) / 4

    tot_score.append([sub, acc_report, prc_report, rcl_report, fsc_report, cnt_report])

year_score = pd.DataFrame(tot_score, columns = ['Year', 'Accuracy', 'Precision', 'Recall', 'F1', 'Support']) 
year_score.to_excel('./Results/Year_Score_Matrix.xlsx')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### 2.4.6. Month Evaluation

# %%
month_report = classification_report(encoded_month, month_pred, target_names=labMonth_tok.classes_, digits=6, zero_division=False, output_dict=True)
print(month_report)
# Out:
# {'April': {'precision': 0.7448979591836735, 'recall': 0.6441176470588236, 'f1-score': 0.6908517350157729, 'support': 340}, 'August': {'precision': 0.7931034482758621, 'recall': 0.6680497925311203, 'f1-score': 0.7252252252252254, 'support': 482}, 'December': {'precision': 0.7514285714285714, 'recall': 0.6159250585480094, 'f1-score': 0.6769626769626771, 'support': 427}, 'February': {'precision': 0.7539936102236422, 'recall': 0.5841584158415841, 'f1-score': 0.6582984658298465, 'support': 404}, 'January': {'precision': 0.8024691358024691, 'recall': 0.6782608695652174, 'f1-score': 0.7351555136663525, 'support': 575}, 'July': {'precision': 0.759075907590759, 'recall': 0.6149732620320856, 'f1-score': 0.6794682422451994, 'support': 374}, 'June': {'precision': 0.8295964125560538, 'recall': 0.5623100303951368, 'f1-score': 0.6702898550724639, 'support': 329}, 'March': {'precision': 0.7355623100303952, 'recall': 0.6019900497512438, 'f1-score': 0.6621067031463749, 'support': 402}, 'May': {'precision': 0.7049180327868853, 'recall': 0.6825396825396826, 'f1-score': 0.6935483870967742, 'support': 441}, 'November': {'precision': 0.8038740920096852, 'recall': 0.6421663442940039, 'f1-score': 0.7139784946236558, 'support': 517}, 'October': {'precision': 0.749003984063745, 'recall': 0.6873857404021938, 'f1-score': 0.7168732125834127, 'support': 547}, 'September': {'precision': 0.7311557788944724, 'recall': 0.6583710407239819, 'f1-score': 0.6928571428571428, 'support': 442}, 'micro avg': {'precision': 0.7621512151215122, 'recall': 0.6414772727272727, 'f1-score': 0.6966269025092555, 'support': 5280}, 'macro avg': {'precision': 0.7632566035705177, 'recall': 0.6366873278069235, 'f1-score': 0.6929679711937414, 'support': 5280}, 'weighted avg': {'precision': 0.7640738237107082, 'recall': 0.6414772727272727, 'f1-score': 0.6962776167651278, 'support': 5280}, 'samples avg': {'precision': 0.6414772727272727, 'recall': 0.6414772727272727, 'f1-score': 0.6414772727272727, 'support': 5280}}

# %%
report = []

for k, v in month_report.items():
    p, r, f, s = v.values()
    report.append([k, p, r, f, s])
report

exportDF = pd.DataFrame(report, columns = ['Class', 'Precision', 'Recall', 'F1', 'Support'])
exportDF.to_excel('./Results/Month_Score_Matrix.xlsx')

# %%
print('Hamming score: {0}'.format(hamming_score(encoded_month, month_pred)))
print('Hamming loss: {0}'.format(sklearn.metrics.hamming_loss(encoded_month, month_pred))) 
print('Subset accuracy: {0}'.format(sklearn.metrics.accuracy_score(encoded_month, month_pred, normalize=True, sample_weight=None)))
# Out:
# Hamming score: 0.6414772727272727
# Hamming loss: 0.04655934343434343
# Subset accuracy: 0.6414772727272727

# %%
tot_score = []

for idx, sub in enumerate(labMonth_tok.classes_):

    subDF = normDF.loc[normDF['month_created'].str.contains(sub)]

    cnt_report = len(subDF)
    if cnt_report <=0 : continue

    inpText = subDF['text'].tolist()
    inpText = [' '.join(str(d).lower().split()[:max_word]) for d in inpText]
    inpText = texts_tok.texts_to_sequences(inpText)
    inpText = pad_sequences(inpText, maxlen=padding_len, padding='post', truncating='post')

    outMonth = [[sub]] * cnt_report
    outMonth = labMonth_tok.transform(outMonth)

    preActor, preAgency, preSector, prePlace, preYear, preMonth, preReason, preGoal, preStat = model.predict(inpText, verbose=0)

    preMonth = np.where(preMonth>=0.5, 1, 0)

    acc_report = sklearn.metrics.accuracy_score(outMonth, preMonth, normalize=True)
    prc_report = sklearn.metrics.precision_score(outMonth, preMonth, average='micro')
    rcl_report = sklearn.metrics.recall_score(outMonth, preMonth, average='micro')
    fsc_report = sklearn.metrics.f1_score(outMonth, preMonth, average='micro')
    avg_report = (acc_report + prc_report + rcl_report + fsc_report) / 4

    tot_score.append([sub, acc_report, prc_report, rcl_report, fsc_report, cnt_report])

month_score = pd.DataFrame(tot_score, columns = ['Month', 'Accuracy', 'Precision', 'Recall', 'F1', 'Support']) 
month_score.to_excel('./Results/Month_Score_Matrix.xlsx')

# %% [markdown]
# ### 2.4.7. Reason Evaluation

# %%
reason_report = classification_report(encoded_reason, reason_pred, target_names=labReason_tok.classes_, digits=6, zero_division=False, output_dict=True)
print(reason_report)
# Out:
# {'Cold Wave': {'precision': 0.918918918918919, 'recall': 0.7083333333333334, 'f1-score': 0.8000000000000002, 'support': 48}, 'Drought': {'precision': 0.9593810444874274, 'recall': 0.5714285714285714, 'f1-score': 0.716245487364621, 'support': 868}, 'Earthquake': {'precision': 0.9768888888888889, 'recall': 0.7616077616077616, 'f1-score': 0.8559190031152648, 'support': 1443}, 'Epidemic': {'precision': 0.9852125693160814, 'recall': 0.8766447368421053, 'f1-score': 0.927763272410792, 'support': 608}, 'Extratropical Cyclone': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 3}, 'Fire': {'precision': 1.0, 'recall': 0.3333333333333333, 'f1-score': 0.5, 'support': 3}, 'Flash Flood': {'precision': 0.9821428571428571, 'recall': 0.07333333333333333, 'f1-score': 0.13647642679900743, 'support': 750}, 'Flood': {'precision': 0.9580908032596042, 'recall': 0.4824150058616647, 'f1-score': 0.6417153996101365, 'support': 1706}, 'Heat Wave': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 6}, 'Insect Infestation': {'precision': 0.9661016949152542, 'recall': 0.8028169014084507, 'f1-score': 0.876923076923077, 'support': 71}, 'Land Slide': {'precision': 0.9607843137254902, 'recall': 0.06464379947229551, 'f1-score': 0.12113720642768849, 'support': 758}, 'Mud Slide': {'precision': 0.5, 'recall': 0.012658227848101266, 'f1-score': 0.02469135802469136, 'support': 79}, 'Other': {'precision': 0.9714285714285714, 'recall': 0.3965014577259475, 'f1-score': 0.5631469979296067, 'support': 686}, 'Severe Local Storm': {'precision': 1.0, 'recall': 0.16666666666666666, 'f1-score': 0.2857142857142857, 'support': 54}, 'Snow Avalanche': {'precision': 1.0, 'recall': 0.5, 'f1-score': 0.6666666666666666, 'support': 6}, 'Storm Surge': {'precision': 1.0, 'recall': 0.020066889632107024, 'f1-score': 0.03934426229508197, 'support': 299}, 'Technological Disaster': {'precision': 1.0, 'recall': 0.3333333333333333, 'f1-score': 0.5, 'support': 90}, 'Tropical Cyclone': {'precision': 0.958904109589041, 'recall': 0.49733570159857904, 'f1-score': 0.6549707602339181, 'support': 1126}, 'Tsunami': {'precision': 0.9897959183673469, 'recall': 0.381139489194499, 'f1-score': 0.550354609929078, 'support': 509}, 'Volcano': {'precision': 0.975609756097561, 'recall': 0.7272727272727273, 'f1-score': 0.8333333333333334, 'support': 55}, 'Wild Fire': {'precision': 0.8571428571428571, 'recall': 0.5454545454545454, 'f1-score': 0.6666666666666665, 'support': 11}, 'micro avg': {'precision': 0.9691189827429609, 'recall': 0.4649743980825798, 'f1-score': 0.6284325995729957, 'support': 9179}, 'macro avg': {'precision': 0.855257252537138, 'recall': 0.39309456263558834, 'f1-score': 0.49338422921161507, 'support': 9179}, 'weighted avg': {'precision': 0.9650297205311198, 'recall': 0.4649743980825798, 'f1-score': 0.5825510196953779, 'support': 9179}, 'samples avg': {'precision': 0.8083333333333333, 'recall': 0.6574273989898989, 'f1-score': 0.7047041847041846, 'support': 9179}}

# %%
report = []

for k, v in reason_report.items():
    p, r, f, s = v.values()
    report.append([k, p, r, f, s])
report

exportDF = pd.DataFrame(report, columns = ['Class', 'Precision', 'Recall', 'F1', 'Support'])
exportDF.to_excel('./Results/Reason_Score_Matrix.xlsx')

# %%
print('Hamming score: {0}'.format(hamming_score(encoded_reason, reason_pred)))
print('Hamming loss: {0}'.format(sklearn.metrics.hamming_loss(encoded_reason, reason_pred))) 
print('Subset accuracy: {0}'.format(sklearn.metrics.accuracy_score(encoded_reason, reason_pred, normalize=True, sample_weight=None)))
# Out:
# Hamming score: 0.6574273989898989
# Hamming loss: 0.04551767676767677
# Subset accuracy: 0.5234848484848484

# %%
tot_score = []

for idx, sub in enumerate(labReason_tok.classes_):

    subDF = normDF.loc[normDF['disaster_type'].str.contains(sub)]

    cnt_report = len(subDF)
    if cnt_report <=0 : continue

    inpText = subDF['text'].tolist()
    inpText = [' '.join(str(d).lower().split()[:max_word]) for d in inpText]
    inpText = texts_tok.texts_to_sequences(inpText)
    inpText = pad_sequences(inpText, maxlen=padding_len, padding='post', truncating='post')

    outReason = [[sub]] * cnt_report
    outReason = labReason_tok.transform(outReason)

    preActor, preAgency, preSector, prePlace, preYear, preMonth, preReason, preGoal, preStat = model.predict(inpText, verbose=0)

    preReason = np.where(preReason>=0.5, 1, 0)

    acc_report = sklearn.metrics.accuracy_score(outReason, preReason, normalize=True)
    prc_report = sklearn.metrics.precision_score(outReason, preReason, average='micro')
    rcl_report = sklearn.metrics.recall_score(outReason, preReason, average='micro')
    fsc_report = sklearn.metrics.f1_score(outReason, preReason, average='micro')
    avg_report = (acc_report + prc_report + rcl_report + fsc_report) / 4

    tot_score.append([sub, acc_report, prc_report, rcl_report, fsc_report, cnt_report])

reason_score = pd.DataFrame(tot_score, columns = ['Reason', 'Accuracy', 'Precision', 'Recall', 'F1', 'Support']) 
reason_score.to_excel('./Results/Reason_Score_Matrix.xlsx')

# %% [markdown]
# ### 2.4.8. SDG Evaluation

# %%
goal_report = classification_report(encoded_goal, goal_pred, target_names=labGoal_tok.classes_, digits=6, zero_division=False, output_dict=True)
print(goal_report)
# Out:
# {'Affordable and Clean Energy': {'precision': 1.0, 'recall': 0.6666666666666666, 'f1-score': 0.8, 'support': 3}, 'Clean Water and Sanitation': {'precision': 0.8538011695906432, 'recall': 0.5816733067729084, 'f1-score': 0.6919431279620853, 'support': 251}, 'Climate Action': {'precision': 0.7568807339449541, 'recall': 0.6066176470588235, 'f1-score': 0.673469387755102, 'support': 272}, 'Decent Work and Economic Growth': {'precision': 0.7575757575757576, 'recall': 0.5813953488372093, 'f1-score': 0.6578947368421053, 'support': 43}, 'Gender Equality': {'precision': 1.0, 'recall': 0.2, 'f1-score': 0.33333333333333337, 'support': 5}, 'Good Health and Well-being': {'precision': 0.7573415765069552, 'recall': 0.7401812688821753, 'f1-score': 0.7486631016042782, 'support': 662}, 'Industry Innovation and Infrastructure': {'precision': 0.7105966162065895, 'recall': 0.6779949022939677, 'f1-score': 0.6939130434782609, 'support': 1177}, 'Life Below Water': {'precision': 0.7007299270072993, 'recall': 0.5517241379310345, 'f1-score': 0.617363344051447, 'support': 174}, 'Life On Land': {'precision': 0.808641975308642, 'recall': 0.5198412698412699, 'f1-score': 0.6328502415458939, 'support': 252}, 'No Poverty': {'precision': 1.0, 'recall': 0.125, 'f1-score': 0.2222222222222222, 'support': 8}, 'Peace Justice and Strong Institutions': {'precision': 0.8363636363636363, 'recall': 0.6174496644295302, 'f1-score': 0.7104247104247103, 'support': 149}, 'Quality Education': {'precision': 0.851063829787234, 'recall': 0.6153846153846154, 'f1-score': 0.7142857142857144, 'support': 65}, 'Reducing Inequality': {'precision': 0.8363636363636363, 'recall': 0.6666666666666666, 'f1-score': 0.7419354838709676, 'support': 69}, 'Responsible Consumption and Production': {'precision': 1.0, 'recall': 0.4, 'f1-score': 0.5714285714285715, 'support': 15}, 'Sustainable Cities and Communities': {'precision': 0.8039617486338798, 'recall': 0.7642857142857142, 'f1-score': 0.7836218375499334, 'support': 1540}, 'Zero Hunger': {'precision': 0.798941798941799, 'recall': 0.761344537815126, 'f1-score': 0.7796901893287435, 'support': 595}, 'micro avg': {'precision': 0.773397976391231, 'recall': 0.6948863636363637, 'f1-score': 0.7320430965682363, 'support': 5280}, 'macro avg': {'precision': 0.8420164003894391, 'recall': 0.5672641091791067, 'f1-score': 0.6483149403552105, 'support': 5280}, 'weighted avg': {'precision': 0.7761943980503471, 'recall': 0.6948863636363637, 'f1-score': 0.7297321112888006, 'support': 5280}, 'samples avg': {'precision': 0.6948863636363637, 'recall': 0.6948863636363637, 'f1-score': 0.6948863636363637, 'support': 5280}}

# %%
report = []

for k, v in goal_report.items():
    p, r, f, s = v.values()
    report.append([k, p, r, f, s])
report

exportDF = pd.DataFrame(report, columns = ['Class', 'Precision', 'Recall', 'F1', 'Support'])
exportDF.to_excel('./Results/Goal_Score_Matrix.xlsx')

# %%
print('Hamming score: {0}'.format(hamming_score(encoded_goal, goal_pred)))
print('Hamming loss: {0}'.format(sklearn.metrics.hamming_loss(encoded_goal, goal_pred))) 
print('Subset accuracy: {0}'.format(sklearn.metrics.accuracy_score(encoded_goal, goal_pred, normalize=True, sample_weight=None)))
# Out:
# Hamming score: 0.6948863636363637
# Hamming loss: 0.03179450757575757
# Subset accuracy: 0.6948863636363637

# %%
tot_score = []

for idx, sub in enumerate(labGoal_tok.classes_):

    subDF = normDF.loc[normDF['development_goal'].str.contains(sub)]

    cnt_report = len(subDF)
    if cnt_report <=0 : continue

    inpText = subDF['text'].tolist()
    inpText = [' '.join(str(d).lower().split()[:max_word]) for d in inpText]
    inpText = texts_tok.texts_to_sequences(inpText)
    inpText = pad_sequences(inpText, maxlen=padding_len, padding='post', truncating='post')

    outGoal = [[sub]] * cnt_report
    outGoal = labGoal_tok.transform(outGoal)

    preActor, preAgency, preSector, prePlace, preYear, preMonth, preReason, preGoal, preStat = model.predict(inpText, verbose=0)

    preGoal = np.where(preGoal>=0.5, 1, 0)

    acc_report = sklearn.metrics.accuracy_score(outGoal, preGoal, normalize=True)
    prc_report = sklearn.metrics.precision_score(outGoal, preGoal, average='micro')
    rcl_report = sklearn.metrics.recall_score(outGoal, preGoal, average='micro')
    fsc_report = sklearn.metrics.f1_score(outGoal, preGoal, average='micro')
    avg_report = (acc_report + prc_report + rcl_report + fsc_report) / 4
    
    tot_score.append([sub, acc_report, prc_report, rcl_report, fsc_report, cnt_report])

goal_score = pd.DataFrame(tot_score, columns = ['Goal', 'Accuracy', 'Precision', 'Recall', 'F1', 'Support']) 
goal_score.to_excel('./Results/Goal_Score_Matrix.xlsx')

# %% [markdown]
# # 3. Results Testing

# %% [markdown]
# ## 3.1. Internal Test (ReliefWeb)

# %%
docs = normDF['common_words'].tolist()
randActor = normDF['source_name'].tolist()
randAgency = normDF['source_type'].tolist()
randSector = normDF['theme'].tolist()
randPlace = normDF['country_name'].tolist()
randMonth = normDF['date_created'].tolist()
randReason = normDF['disaster_type'].tolist()
randGoal = normDF['development_goal'].tolist()

# %%
print('++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++\n')
print(f'This is a data sub-set of 20 instances randomly picked from the main set used to train this model\n')
print('++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++\n')

randDF = normDF
randDF = normDF.sample(n = 20)

for idx, row in enumerate(randDF.itertuples()):
    
    actText = row.text
    actActor = eval(row.source_name)
    actAgency = eval(row.source_type)
    actSector = eval(row.theme)
    actPlace = eval(row.country_name)
    actYear = eval(row.year_created)
    actMonth = eval(row.month_created)
    actReason = eval(row.disaster_type)
    actGoal = eval(row.development_goal)

    preText = texts_tok.texts_to_sequences([actText])[0]
    preText = np.array([preText])
    preText = pad_sequences(preText, maxlen=padding_len)

    outActor, outAgency, outSector, outPlace, outYear, outMonth, outReason, outGoal, outStat = model.predict(preText, verbose=0)

    maxActor = np.where(outActor>=np.sort(outActor[0])[-len(set(actActor))], 1, 0)
    maxAgency = np.where(outAgency>=np.sort(outAgency[0])[-len(set(actAgency))], 1, 0)
    maxSector = np.where(outSector>=np.sort(outSector[0])[-len(set(actSector))], 1, 0)
    maxPlace = np.where(outPlace>=np.sort(outPlace[0])[-len(set(actPlace))], 1, 0)
    maxYear = np.where(outYear>=np.sort(outYear[0])[-len(set(actYear))], 1, 0)
    maxMonth = np.where(outMonth>=np.sort(outMonth[0])[-len(set(actMonth))], 1, 0)
    maxReason = np.where(outReason>=np.sort(outReason[0])[-len(set(actReason))], 1, 0)
    maxGoal = np.where(outGoal>=np.sort(outGoal[0])[-len(set(actGoal))], 1, 0)

    preActor = labActor_tok.inverse_transform(maxActor)
    preAgency = labAgency_tok.inverse_transform(maxAgency)
    preSector = labSector_tok.inverse_transform(maxSector)
    prePlace = labPlace_tok.inverse_transform(maxPlace)
    preYear = labYear_tok.inverse_transform(maxYear)
    preMonth = labMonth_tok.inverse_transform(maxMonth)
    preReason = labReason_tok.inverse_transform(maxReason)
    preGoal = labGoal_tok.inverse_transform(maxGoal)
    
    print(f'The text used in sample [{idx}] is: {row.text[:80]} ......')
    print(f'Overall confidence in this prediction is: {round(outStat[0][0]*100, 2)}%\n')

    print(f'Actual Actor for this disaster is: {actActor}')
    print(f'Predicted Actor for this disaster is: {preActor}')
    print(f'Confidence in this prediction is: {round(np.sort(outActor[0])[-1] * 100, 2)}%\n')

    print(f'Actual Agency for this disaster is: {actAgency}')
    print(f'Predicted Agency for this disaster is: {preAgency}')
    print(f'Confidence in this prediction is: {round(np.sort(outAgency[0])[-1] * 100, 2)}%\n')

    print(f'Actual Sector for this disaster is: {actSector}')
    print(f'Predicted Sector for this disaster is: {preSector}')
    print(f'Confidence in this prediction is: {round(np.sort(outSector[0])[-1] * 100, 2)}%\n')

    print(f'Actual Place for this disaster is: {actPlace}')
    print(f'Predicted Place for this disaster is: {prePlace}')
    print(f'Confidence in this prediction is: {round(np.sort(outPlace[0])[-1] * 100, 2)}%\n')

    print(f'Actual Year for this disaster is: {actYear}')
    print(f'Predicted Year for this disaster is: {preYear}')
    print(f'Confidence in this prediction is: {round(np.sort(outYear[0])[-1] * 100, 2)}%\n')

    print(f'Actual Month for this disaster is: {actMonth}')
    print(f'Predicted Month for this disaster is: {preMonth}')
    print(f'Confidence in this prediction is: {round(np.sort(outMonth[0])[-1] * 100, 2)}%\n')

    print(f'Actual Reason for this disaster is: {actReason}')
    print(f'Predicted Reason for this disaster is: {preReason}')
    print(f'Confidence in this prediction is: {round(np.sort(outReason[0])[-1] * 100, 2)}%\n')

    print(f'Actual SDG for this disaster is: {actGoal}')
    print(f'Predicted SDG for this disaster is: {preGoal}')
    print(f'Confidence in this prediction is: {round(np.sort(outGoal[0])[-1] * 100, 2)}%\n')

    print('------------------------------------------------------------------------------------------------\n')
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# This is a data sub-set of 20 instances randomly picked from the main set used to train this model
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# The text used in sample [0] is: funds sent national council churches philippines nccp amount sent us 50000 date  ......
# Overall confidence in this prediction is: 99.04%
#
# Actual Actor for this disaster is: ['Action by Churches Together International']
# Predicted Actor for this disaster is: [('Government of the Philippines',)]
# Confidence in this prediction is: 72.77%
#
# Actual Agency for this disaster is: ['Non-governmental Organization']
# Predicted Agency for this disaster is: [('Non-governmental Organization',)]
# Confidence in this prediction is: 57.17%
#
# Actual Sector for this disaster is: ['Shelter and Non-Food Items', 'Food and Nutrition', 'Water Sanitation Hygiene', 'Contributions']
# Predicted Sector for this disaster is: [('Food and Nutrition', 'Health', 'Shelter and Non-Food Items', 'Water Sanitation Hygiene')]
# Confidence in this prediction is: 50.82%
#
# Actual Place for this disaster is: ['Philippines']
# Predicted Place for this disaster is: [('Philippines',)]
# Confidence in this prediction is: 99.87%
#
# Actual Year for this disaster is: ['2006']
# Predicted Year for this disaster is: [('2006',)]
# Confidence in this prediction is: 91.23%
#
# Actual Month for this disaster is: ['December']
# Predicted Month for this disaster is: [('October',)]
# Confidence in this prediction is: 80.7%
#
# Actual Reason for this disaster is: ['Tropical Cyclone']
# Predicted Reason for this disaster is: [('Volcano',)]
# Confidence in this prediction is: 76.03%
#
# Actual SDG for this disaster is: ['Industry Innovation and Infrastructure']
# Predicted SDG for this disaster is: [('Clean Water and Sanitation',)]
# Confidence in this prediction is: 33.94%
#
# ------------------------------------------------------------------------------------------------
#
# The text used in sample [1] is: another mobile laboratory set sierra leone canadian armed forces personnel depar ......
# Overall confidence in this prediction is: 98.67%
#
# Actual Actor for this disaster is: ['Government of Canada']
# Predicted Actor for this disaster is: [('Government of Canada',)]
# Confidence in this prediction is: 66.14%
#
# Actual Agency for this disaster is: ['Government']
# Predicted Agency for this disaster is: [('Government',)]
# Confidence in this prediction is: 99.52%
#
# Actual Sector for this disaster is: ['Contributions', 'Health']
# Predicted Sector for this disaster is: [('Contributions', 'Health')]
# Confidence in this prediction is: 68.18%
#
# Actual Place for this disaster is: ['Sierra Leone']
# Predicted Place for this disaster is: [('Liberia',)]
# Confidence in this prediction is: 82.91%
#
# Actual Year for this disaster is: ['2014']
# Predicted Year for this disaster is: [('2014',)]
# Confidence in this prediction is: 100.0%
#
# Actual Month for this disaster is: ['December']
# Predicted Month for this disaster is: [('May',)]
# Confidence in this prediction is: 36.56%
#
# Actual Reason for this disaster is: ['Epidemic']
# Predicted Reason for this disaster is: [('Epidemic',)]
# Confidence in this prediction is: 99.63%
#
# Actual SDG for this disaster is: ['Industry Innovation and Infrastructure']
# Predicted SDG for this disaster is: [('Good Health and Well-being',)]
# Confidence in this prediction is: 62.88%
#
# ------------------------------------------------------------------------------------------------
#
# The text used in sample [2] is: 17 oclock april 16 red cross society china rcsc received donation rmb 31.5 milli ......
# Overall confidence in this prediction is: 98.95%
#
# Actual Actor for this disaster is: ['Red Cross Society of China']
# Predicted Actor for this disaster is: [('Red Cross Society of China',)]
# Confidence in this prediction is: 99.99%
#
# Actual Agency for this disaster is: ['Red Cross/Red Crescent Movement']
# Predicted Agency for this disaster is: [('Red Cross/Red Crescent Movement',)]
# Confidence in this prediction is: 97.32%
#
# Actual Sector for this disaster is: ['Coordination', 'Contributions']
# Predicted Sector for this disaster is: [('Contributions', 'Coordination')]
# Confidence in this prediction is: 53.15%
#
# Actual Place for this disaster is: ['China']
# Predicted Place for this disaster is: [('China',)]
# Confidence in this prediction is: 100.0%
#
# Actual Year for this disaster is: ['2010']
# Predicted Year for this disaster is: [('2010',)]
# Confidence in this prediction is: 99.34%
#
# Actual Month for this disaster is: ['April']
# Predicted Month for this disaster is: [('May',)]
# Confidence in this prediction is: 92.64%
#
# Actual Reason for this disaster is: ['Earthquake']
# Predicted Reason for this disaster is: [('Earthquake',)]
# Confidence in this prediction is: 95.77%
#
# Actual SDG for this disaster is: ['Industry Innovation and Infrastructure']
# Predicted SDG for this disaster is: [('Industry Innovation and Infrastructure',)]
# Confidence in this prediction is: 94.61%
#
# ------------------------------------------------------------------------------------------------
#
# The text used in sample [3] is: mark kaye head never really suited buzz cut hair cut short draws attention fact  ......
# Overall confidence in this prediction is: 99.32%
#
# Actual Actor for this disaster is: ['Save the Children']
# Predicted Actor for this disaster is: [('Agency for Technical Cooperation and Development',)]
# Confidence in this prediction is: 22.6%
#
# Actual Agency for this disaster is: ['Non-governmental Organization']
# Predicted Agency for this disaster is: [('Non-governmental Organization',)]
# Confidence in this prediction is: 82.52%
#
# Actual Sector for this disaster is: ['Recovery and Reconstruction']
# Predicted Sector for this disaster is: [('Recovery and Reconstruction',)]
# Confidence in this prediction is: 99.01%
#
# Actual Place for this disaster is: ['Somalia']
# Predicted Place for this disaster is: [("Côte d'Ivoire",)]
# Confidence in this prediction is: 32.69%
#
# Actual Year for this disaster is: ['2012']
# Predicted Year for this disaster is: [('2012',)]
# Confidence in this prediction is: 96.03%
#
# Actual Month for this disaster is: ['October']
# Predicted Month for this disaster is: [('January',)]
# Confidence in this prediction is: 30.41%
#
# Actual Reason for this disaster is: ['Drought', 'Other']
# Predicted Reason for this disaster is: [('Drought', 'Other')]
# Confidence in this prediction is: 53.7%
#
# Actual SDG for this disaster is: ['Reducing Inequality']
# Predicted SDG for this disaster is: [('Reducing Inequality',)]
# Confidence in this prediction is: 71.22%
#
# ------------------------------------------------------------------------------------------------
#
# The text used in sample [4] is: last update january 1st 2005 20.00h information expected january 2nd 2005 emerge ......
# Overall confidence in this prediction is: 98.09%
#
# Actual Actor for this disaster is: ['Swiss Agency for Development and Cooperation']
# Predicted Actor for this disaster is: [('Swiss Agency for Development and Cooperation',)]
# Confidence in this prediction is: 39.08%
#
# Actual Agency for this disaster is: ['Government']
# Predicted Agency for this disaster is: [('Government',)]
# Confidence in this prediction is: 99.03%
#
# Actual Sector for this disaster is: ['Health', 'Shelter and Non-Food Items', 'Coordination']
# Predicted Sector for this disaster is: [('Coordination', 'Shelter and Non-Food Items', 'Water Sanitation Hygiene')]
# Confidence in this prediction is: 69.79%
#
# Actual Place for this disaster is: ['Indonesia']
# Predicted Place for this disaster is: [('Sri Lanka',)]
# Confidence in this prediction is: 47.79%
#
# Actual Year for this disaster is: ['2005']
# Predicted Year for this disaster is: [('2005',)]
# Confidence in this prediction is: 77.08%
#
# Actual Month for this disaster is: ['January']
# Predicted Month for this disaster is: [('January',)]
# Confidence in this prediction is: 95.92%
#
# Actual Reason for this disaster is: ['Earthquake', 'Tsunami']
# Predicted Reason for this disaster is: [('Earthquake', 'Tsunami')]
# Confidence in this prediction is: 54.04%
#
# Actual SDG for this disaster is: ['Industry Innovation and Infrastructure']
# Predicted SDG for this disaster is: [('Industry Innovation and Infrastructure',)]
# Confidence in this prediction is: 96.02%
#
# ------------------------------------------------------------------------------------------------
#
# The text used in sample [5] is: dadaab kenya november 17 unhcr un refugee agency friday withdrew staff higher gr ......
# Overall confidence in this prediction is: 99.11%
#
# Actual Actor for this disaster is: ['UN High Commissioner for Refugees']
# Predicted Actor for this disaster is: [('UN High Commissioner for Refugees',)]
# Confidence in this prediction is: 99.3%
#
# Actual Agency for this disaster is: ['International Organization']
# Predicted Agency for this disaster is: [('International Organization',)]
# Confidence in this prediction is: 91.36%
#
# Actual Sector for this disaster is: ['Shelter and Non-Food Items']
# Predicted Sector for this disaster is: [('Shelter and Non-Food Items',)]
# Confidence in this prediction is: 82.66%
#
# Actual Place for this disaster is: ['Kenya']
# Predicted Place for this disaster is: [('Kenya',)]
# Confidence in this prediction is: 97.55%
#
# Actual Year for this disaster is: ['2006']
# Predicted Year for this disaster is: [('2003',)]
# Confidence in this prediction is: 68.48%
#
# Actual Month for this disaster is: ['November']
# Predicted Month for this disaster is: [('May',)]
# Confidence in this prediction is: 65.31%
#
# Actual Reason for this disaster is: ['Flood']
# Predicted Reason for this disaster is: [('Flood',)]
# Confidence in this prediction is: 85.57%
#
# Actual SDG for this disaster is: ['Industry Innovation and Infrastructure']
# Predicted SDG for this disaster is: [('Industry Innovation and Infrastructure',)]
# Confidence in this prediction is: 99.07%
#
# ------------------------------------------------------------------------------------------------
#
# The text used in sample [6] is: susana.ferreira villambetta port-au-prince haiti wind already picked thursday mo ......
# Overall confidence in this prediction is: 98.57%
#
# Actual Actor for this disaster is: ['International Rescue Committee']
# Predicted Actor for this disaster is: [('Save the Children',)]
# Confidence in this prediction is: 68.15%
#
# Actual Agency for this disaster is: ['Non-governmental Organization']
# Predicted Agency for this disaster is: [('Non-governmental Organization',)]
# Confidence in this prediction is: 82.11%
#
# Actual Sector for this disaster is: ['Coordination', 'Shelter and Non-Food Items']
# Predicted Sector for this disaster is: [('Coordination', 'Shelter and Non-Food Items')]
# Confidence in this prediction is: 43.48%
#
# Actual Place for this disaster is: ['Haiti']
# Predicted Place for this disaster is: [('Haiti',)]
# Confidence in this prediction is: 86.76%
#
# Actual Year for this disaster is: ['2010']
# Predicted Year for this disaster is: [('2010',)]
# Confidence in this prediction is: 99.88%
#
# Actual Month for this disaster is: ['November']
# Predicted Month for this disaster is: [('November',)]
# Confidence in this prediction is: 89.75%
#
# Actual Reason for this disaster is: ['Tropical Cyclone']
# Predicted Reason for this disaster is: [('Tropical Cyclone',)]
# Confidence in this prediction is: 79.2%
#
# Actual SDG for this disaster is: ['Sustainable Cities and Communities']
# Predicted SDG for this disaster is: [('Sustainable Cities and Communities',)]
# Confidence in this prediction is: 89.81%
#
# ------------------------------------------------------------------------------------------------
#
# The text used in sample [7] is: doctors without bordersmédecins sans frontières msf deeply gratified hear confir ......
# Overall confidence in this prediction is: 98.23%
#
# Actual Actor for this disaster is: ['Médecins Sans Frontières']
# Predicted Actor for this disaster is: [('Médecins Sans Frontières',)]
# Confidence in this prediction is: 99.12%
#
# Actual Agency for this disaster is: ['International Organization']
# Predicted Agency for this disaster is: [('International Organization',)]
# Confidence in this prediction is: 99.61%
#
# Actual Sector for this disaster is: ['Safety and Security']
# Predicted Sector for this disaster is: [('Safety and Security',)]
# Confidence in this prediction is: 93.16%
#
# Actual Place for this disaster is: ['Liberia']
# Predicted Place for this disaster is: [('Liberia',)]
# Confidence in this prediction is: 88.08%
#
# Actual Year for this disaster is: ['2014']
# Predicted Year for this disaster is: [('2014',)]
# Confidence in this prediction is: 98.63%
#
# Actual Month for this disaster is: ['October']
# Predicted Month for this disaster is: [('October',)]
# Confidence in this prediction is: 97.48%
#
# Actual Reason for this disaster is: ['Epidemic']
# Predicted Reason for this disaster is: [('Epidemic',)]
# Confidence in this prediction is: 98.29%
#
# Actual SDG for this disaster is: ['Good Health and Well-being']
# Predicted SDG for this disaster is: [('Good Health and Well-being',)]
# Confidence in this prediction is: 98.15%
#
# ------------------------------------------------------------------------------------------------
#
# The text used in sample [8] is: last issue ochaunjlc logistics bottlenecks report information logistics related  ......
# Overall confidence in this prediction is: 98.54%
#
# Actual Actor for this disaster is: ['UN Office for the Coordination of Humanitarian Affairs']
# Predicted Actor for this disaster is: [('UN Joint Logistics Centre',)]
# Confidence in this prediction is: 88.31%
#
# Actual Agency for this disaster is: ['International Organization']
# Predicted Agency for this disaster is: [('International Organization',)]
# Confidence in this prediction is: 99.64%
#
# Actual Sector for this disaster is: ['Coordination']
# Predicted Sector for this disaster is: [('Coordination',)]
# Confidence in this prediction is: 96.89%
#
# Actual Place for this disaster is: ['Pakistan']
# Predicted Place for this disaster is: [('Pakistan',)]
# Confidence in this prediction is: 93.75%
#
# Actual Year for this disaster is: ['2006']
# Predicted Year for this disaster is: [('2006',)]
# Confidence in this prediction is: 81.38%
#
# Actual Month for this disaster is: ['January']
# Predicted Month for this disaster is: [('January',)]
# Confidence in this prediction is: 63.76%
#
# Actual Reason for this disaster is: ['Earthquake', 'Tsunami']
# Predicted Reason for this disaster is: [('Earthquake', 'Tsunami')]
# Confidence in this prediction is: 94.19%
#
# Actual SDG for this disaster is: ['Life On Land']
# Predicted SDG for this disaster is: [('Life On Land',)]
# Confidence in this prediction is: 95.81%
#
# ------------------------------------------------------------------------------------------------
#
# The text used in sample [9] is: contributions people singapore continue improve lives china singapore contributi ......
# Overall confidence in this prediction is: 98.78%
#
# Actual Actor for this disaster is: ['Singapore Red Cross']
# Predicted Actor for this disaster is: [('Singapore Red Cross',)]
# Confidence in this prediction is: 95.79%
#
# Actual Agency for this disaster is: ['Red Cross/Red Crescent Movement']
# Predicted Agency for this disaster is: [('Red Cross/Red Crescent Movement',)]
# Confidence in this prediction is: 75.59%
#
# Actual Sector for this disaster is: ['Health']
# Predicted Sector for this disaster is: [('Health',)]
# Confidence in this prediction is: 72.71%
#
# Actual Place for this disaster is: ['China']
# Predicted Place for this disaster is: [('Japan',)]
# Confidence in this prediction is: 46.81%
#
# Actual Year for this disaster is: ['2013']
# Predicted Year for this disaster is: [('2006',)]
# Confidence in this prediction is: 23.32%
#
# Actual Month for this disaster is: ['April']
# Predicted Month for this disaster is: [('April',)]
# Confidence in this prediction is: 98.29%
#
# Actual Reason for this disaster is: ['Earthquake']
# Predicted Reason for this disaster is: [('Earthquake',)]
# Confidence in this prediction is: 98.06%
#
# Actual SDG for this disaster is: ['Industry Innovation and Infrastructure']
# Predicted SDG for this disaster is: [('Industry Innovation and Infrastructure',)]
# Confidence in this prediction is: 83.23%
#
# ------------------------------------------------------------------------------------------------
#
# The text used in sample [10] is: west bank gaza december 16 2013 mercy corps launched emergency response weekend  ......
# Overall confidence in this prediction is: 98.43%
#
# Actual Actor for this disaster is: ['Mercy Corps']
# Predicted Actor for this disaster is: [('Malteser',)]
# Confidence in this prediction is: 27.46%
#
# Actual Agency for this disaster is: ['Non-governmental Organization']
# Predicted Agency for this disaster is: [('Non-governmental Organization',)]
# Confidence in this prediction is: 92.95%
#
# Actual Sector for this disaster is: ['Shelter and Non-Food Items', 'Water Sanitation Hygiene']
# Predicted Sector for this disaster is: [('Shelter and Non-Food Items', 'Water Sanitation Hygiene')]
# Confidence in this prediction is: 87.09%
#
# Actual Place for this disaster is: ['occupied Palestinian territory']
# Predicted Place for this disaster is: [('occupied Palestinian territory',)]
# Confidence in this prediction is: 91.95%
#
# Actual Year for this disaster is: ['2013']
# Predicted Year for this disaster is: [('2013',)]
# Confidence in this prediction is: 84.38%
#
# Actual Month for this disaster is: ['December']
# Predicted Month for this disaster is: [('December',)]
# Confidence in this prediction is: 83.01%
#
# Actual Reason for this disaster is: ['Cold Wave', 'Flood', 'Severe Local Storm']
# Predicted Reason for this disaster is: [('Cold Wave', 'Flood', 'Severe Local Storm')]
# Confidence in this prediction is: 46.94%
#
# Actual SDG for this disaster is: ['Sustainable Cities and Communities']
# Predicted SDG for this disaster is: [('Clean Water and Sanitation',)]
# Confidence in this prediction is: 53.45%
#
# ------------------------------------------------------------------------------------------------
#
# The text used in sample [11] is: singapore november 2011 donors give south east asia floods appeal 2700 locations ......
# Overall confidence in this prediction is: 98.13%
#
# Actual Actor for this disaster is: ['Singapore Red Cross']
# Predicted Actor for this disaster is: [('Singapore Red Cross',)]
# Confidence in this prediction is: 96.7%
#
# Actual Agency for this disaster is: ['Red Cross/Red Crescent Movement']
# Predicted Agency for this disaster is: [('Red Cross/Red Crescent Movement',)]
# Confidence in this prediction is: 96.38%
#
# Actual Sector for this disaster is: ['Contributions', 'Food and Nutrition', 'Shelter and Non-Food Items']
# Predicted Sector for this disaster is: [('Food and Nutrition', 'Shelter and Non-Food Items', 'Water Sanitation Hygiene')]
# Confidence in this prediction is: 46.23%
#
# Actual Place for this disaster is: ['Thailand']
# Predicted Place for this disaster is: [('Thailand',)]
# Confidence in this prediction is: 75.99%
#
# Actual Year for this disaster is: ['2011']
# Predicted Year for this disaster is: [('2011',)]
# Confidence in this prediction is: 91.91%
#
# Actual Month for this disaster is: ['November']
# Predicted Month for this disaster is: [('November',)]
# Confidence in this prediction is: 81.84%
#
# Actual Reason for this disaster is: ['Flood', 'Flood', 'Tropical Cyclone', 'Flood', 'Tropical Cyclone', 'Tropical Cyclone']
# Predicted Reason for this disaster is: [('Flood', 'Tropical Cyclone')]
# Confidence in this prediction is: 83.74%
#
# Actual SDG for this disaster is: ['Sustainable Cities and Communities']
# Predicted SDG for this disaster is: [('Sustainable Cities and Communities',)]
# Confidence in this prediction is: 80.36%
#
# ------------------------------------------------------------------------------------------------
#
# The text used in sample [12] is: thousands children miss education schools universities used shelter homeless flo ......
# Overall confidence in this prediction is: 98.4%
#
# Actual Actor for this disaster is: ['Save the Children']
# Predicted Actor for this disaster is: [('Save the Children',)]
# Confidence in this prediction is: 98.77%
#
# Actual Agency for this disaster is: ['Non-governmental Organization']
# Predicted Agency for this disaster is: [('Non-governmental Organization',)]
# Confidence in this prediction is: 99.64%
#
# Actual Sector for this disaster is: ['Education']
# Predicted Sector for this disaster is: [('Education',)]
# Confidence in this prediction is: 84.11%
#
# Actual Place for this disaster is: ['Solomon Islands']
# Predicted Place for this disaster is: [('Solomon Islands',)]
# Confidence in this prediction is: 41.23%
#
# Actual Year for this disaster is: ['2014']
# Predicted Year for this disaster is: [('2007',)]
# Confidence in this prediction is: 27.25%
#
# Actual Month for this disaster is: ['April']
# Predicted Month for this disaster is: [('April',)]
# Confidence in this prediction is: 33.03%
#
# Actual Reason for this disaster is: ['Flash Flood', 'Flood', 'Land Slide']
# Predicted Reason for this disaster is: [('Earthquake', 'Flood', 'Tsunami')]
# Confidence in this prediction is: 30.55%
#
# Actual SDG for this disaster is: ['Sustainable Cities and Communities']
# Predicted SDG for this disaster is: [('Sustainable Cities and Communities',)]
# Confidence in this prediction is: 74.05%
#
# ------------------------------------------------------------------------------------------------
#
# The text used in sample [13] is: april 2015 accessibility remote communities proven logistical challenge aid agen ......
# Overall confidence in this prediction is: 98.43%
#
# Actual Actor for this disaster is: ['GlobalMedic']
# Predicted Actor for this disaster is: [('GlobalMedic',)]
# Confidence in this prediction is: 98.55%
#
# Actual Agency for this disaster is: ['Non-governmental Organization']
# Predicted Agency for this disaster is: [('Non-governmental Organization',)]
# Confidence in this prediction is: 99.07%
#
# Actual Sector for this disaster is: ['Agriculture', 'Shelter and Non-Food Items', 'Water Sanitation Hygiene']
# Predicted Sector for this disaster is: [('Agriculture', 'Shelter and Non-Food Items', 'Water Sanitation Hygiene')]
# Confidence in this prediction is: 97.87%
#
# Actual Place for this disaster is: ['Vanuatu']
# Predicted Place for this disaster is: [('Vanuatu',)]
# Confidence in this prediction is: 92.28%
#
# Actual Year for this disaster is: ['2015']
# Predicted Year for this disaster is: [('2015',)]
# Confidence in this prediction is: 98.04%
#
# Actual Month for this disaster is: ['April']
# Predicted Month for this disaster is: [('April',)]
# Confidence in this prediction is: 67.52%
#
# Actual Reason for this disaster is: ['Flood', 'Storm Surge', 'Tropical Cyclone']
# Predicted Reason for this disaster is: [('Flood', 'Storm Surge', 'Tropical Cyclone')]
# Confidence in this prediction is: 80.18%
#
# Actual SDG for this disaster is: ['Life Below Water']
# Predicted SDG for this disaster is: [('Life Below Water',)]
# Confidence in this prediction is: 42.48%
#
# ------------------------------------------------------------------------------------------------
#
# The text used in sample [14] is: washington november 18 2008 following project approved yesterday world bank boar ......
# Overall confidence in this prediction is: 98.14%
#
# Actual Actor for this disaster is: ['World Bank']
# Predicted Actor for this disaster is: [('World Bank',)]
# Confidence in this prediction is: 88.28%
#
# Actual Agency for this disaster is: ['International Organization']
# Predicted Agency for this disaster is: [('International Organization',)]
# Confidence in this prediction is: 91.6%
#
# Actual Sector for this disaster is: ['Recovery and Reconstruction']
# Predicted Sector for this disaster is: [('Contributions',)]
# Confidence in this prediction is: 52.03%
#
# Actual Place for this disaster is: ['Haiti']
# Predicted Place for this disaster is: [('Haiti',)]
# Confidence in this prediction is: 37.19%
#
# Actual Year for this disaster is: ['2008']
# Predicted Year for this disaster is: [('2009',)]
# Confidence in this prediction is: 55.69%
#
# Actual Month for this disaster is: ['November']
# Predicted Month for this disaster is: [('November',)]
# Confidence in this prediction is: 90.03%
#
# Actual Reason for this disaster is: ['Tropical Cyclone', 'Tropical Cyclone', 'Tropical Cyclone', 'Tropical Cyclone']
# Predicted Reason for this disaster is: [('Tropical Cyclone',)]
# Confidence in this prediction is: 79.45%
#
# Actual SDG for this disaster is: ['Climate Action']
# Predicted SDG for this disaster is: [('Sustainable Cities and Communities',)]
# Confidence in this prediction is: 97.1%
#
# ------------------------------------------------------------------------------------------------
#
# The text used in sample [15] is: crisis currently affecting mali forced thousands persons flee country many found ......
# Overall confidence in this prediction is: 98.68%
#
# Actual Actor for this disaster is: ['Agency for Technical Cooperation and Development']
# Predicted Actor for this disaster is: [('Agency for Technical Cooperation and Development',)]
# Confidence in this prediction is: 84.78%
#
# Actual Agency for this disaster is: ['Non-governmental Organization']
# Predicted Agency for this disaster is: [('Non-governmental Organization',)]
# Confidence in this prediction is: 99.76%
#
# Actual Sector for this disaster is: ['Food and Nutrition', 'Shelter and Non-Food Items', 'Water Sanitation Hygiene']
# Predicted Sector for this disaster is: [('Food and Nutrition', 'Shelter and Non-Food Items', 'Water Sanitation Hygiene')]
# Confidence in this prediction is: 36.47%
#
# Actual Place for this disaster is: ['Mali']
# Predicted Place for this disaster is: [('Sierra Leone',)]
# Confidence in this prediction is: 32.72%
#
# Actual Year for this disaster is: ['2012']
# Predicted Year for this disaster is: [('2012',)]
# Confidence in this prediction is: 99.53%
#
# Actual Month for this disaster is: ['April']
# Predicted Month for this disaster is: [('April',)]
# Confidence in this prediction is: 86.11%
#
# Actual Reason for this disaster is: ['Drought', 'Other']
# Predicted Reason for this disaster is: [('Drought', 'Other')]
# Confidence in this prediction is: 58.78%
#
# Actual SDG for this disaster is: ['Life On Land']
# Predicted SDG for this disaster is: [('Life On Land',)]
# Confidence in this prediction is: 82.32%
#
# ------------------------------------------------------------------------------------------------
#
# The text used in sample [16] is: 1. october government japan decided extend emergency grant aid amounting usd 10  ......
# Overall confidence in this prediction is: 98.55%
#
# Actual Actor for this disaster is: ['Government of Japan']
# Predicted Actor for this disaster is: [('Government of Japan',)]
# Confidence in this prediction is: 43.58%
#
# Actual Agency for this disaster is: ['Government']
# Predicted Agency for this disaster is: [('International Organization',)]
# Confidence in this prediction is: 71.69%
#
# Actual Sector for this disaster is: ['Contributions', 'Education']
# Predicted Sector for this disaster is: [('Contributions', 'Recovery and Reconstruction')]
# Confidence in this prediction is: 53.91%
#
# Actual Place for this disaster is: ['Myanmar']
# Predicted Place for this disaster is: [('Myanmar',)]
# Confidence in this prediction is: 79.21%
#
# Actual Year for this disaster is: ['2015']
# Predicted Year for this disaster is: [('2015',)]
# Confidence in this prediction is: 35.94%
#
# Actual Month for this disaster is: ['October']
# Predicted Month for this disaster is: [('December',)]
# Confidence in this prediction is: 70.79%
#
# Actual Reason for this disaster is: ['Flood', 'Land Slide']
# Predicted Reason for this disaster is: [('Flood', 'Tropical Cyclone')]
# Confidence in this prediction is: 69.87%
#
# Actual SDG for this disaster is: ['Climate Action']
# Predicted SDG for this disaster is: [('Zero Hunger',)]
# Confidence in this prediction is: 42.77%
#
# ------------------------------------------------------------------------------------------------
#
# The text used in sample [17] is: bangkok 27 february 2016 nnt government spokesman sansern kaewkamnerd confirmed  ......
# Overall confidence in this prediction is: 98.86%
#
# Actual Actor for this disaster is: ['Government of Thailand']
# Predicted Actor for this disaster is: [('Government of Thailand',)]
# Confidence in this prediction is: 84.12%
#
# Actual Agency for this disaster is: ['Government']
# Predicted Agency for this disaster is: [('Government',)]
# Confidence in this prediction is: 98.89%
#
# Actual Sector for this disaster is: ['Agriculture', 'Water Sanitation Hygiene']
# Predicted Sector for this disaster is: [('Agriculture', 'Water Sanitation Hygiene')]
# Confidence in this prediction is: 82.75%
#
# Actual Place for this disaster is: ['Thailand']
# Predicted Place for this disaster is: [('Thailand',)]
# Confidence in this prediction is: 99.51%
#
# Actual Year for this disaster is: ['2016']
# Predicted Year for this disaster is: [('2016',)]
# Confidence in this prediction is: 98.55%
#
# Actual Month for this disaster is: ['February']
# Predicted Month for this disaster is: [('February',)]
# Confidence in this prediction is: 73.31%
#
# Actual Reason for this disaster is: ['Drought']
# Predicted Reason for this disaster is: [('Drought',)]
# Confidence in this prediction is: 96.21%
#
# Actual SDG for this disaster is: ['Zero Hunger']
# Predicted SDG for this disaster is: [('Life On Land',)]
# Confidence in this prediction is: 72.51%
#
# ------------------------------------------------------------------------------------------------
#
# The text used in sample [18] is: barclays bank contributed 100000 regard uganda red cross society appeal shs4.2 b ......
# Overall confidence in this prediction is: 99.07%
#
# Actual Actor for this disaster is: ['Uganda Red Cross']
# Predicted Actor for this disaster is: [('Uganda Red Cross',)]
# Confidence in this prediction is: 99.67%
#
# Actual Agency for this disaster is: ['Red Cross/Red Crescent Movement']
# Predicted Agency for this disaster is: [('Red Cross/Red Crescent Movement',)]
# Confidence in this prediction is: 98.94%
#
# Actual Sector for this disaster is: ['Shelter and Non-Food Items', 'Food and Nutrition', 'Agriculture', 'Contributions']
# Predicted Sector for this disaster is: [('Agriculture', 'Food and Nutrition', 'Shelter and Non-Food Items', 'Water Sanitation Hygiene')]
# Confidence in this prediction is: 66.93%
#
# Actual Place for this disaster is: ['Uganda']
# Predicted Place for this disaster is: [('Uganda',)]
# Confidence in this prediction is: 99.88%
#
# Actual Year for this disaster is: ['2007']
# Predicted Year for this disaster is: [('2007',)]
# Confidence in this prediction is: 96.56%
#
# Actual Month for this disaster is: ['October']
# Predicted Month for this disaster is: [('December',)]
# Confidence in this prediction is: 35.78%
#
# Actual Reason for this disaster is: ['Flood', 'Flood']
# Predicted Reason for this disaster is: [('Flood',)]
# Confidence in this prediction is: 83.79%
#
# Actual SDG for this disaster is: ['Industry Innovation and Infrastructure']
# Predicted SDG for this disaster is: [('Industry Innovation and Infrastructure',)]
# Confidence in this prediction is: 78.82%
#
# ------------------------------------------------------------------------------------------------
#
# The text used in sample [19] is: act appeal assa51 revision emergency relief quake-affected geneva may 12 2006 pa ......
# Overall confidence in this prediction is: 99.11%
#
# Actual Actor for this disaster is: ['Action by Churches Together International']
# Predicted Actor for this disaster is: [('Medair',)]
# Confidence in this prediction is: 67.34%
#
# Actual Agency for this disaster is: ['Non-governmental Organization']
# Predicted Agency for this disaster is: [('Non-governmental Organization',)]
# Confidence in this prediction is: 99.73%
#
# Actual Sector for this disaster is: ['Water Sanitation Hygiene', 'Health', 'Coordination', 'Shelter and Non-Food Items']
# Predicted Sector for this disaster is: [('Health', 'Recovery and Reconstruction', 'Shelter and Non-Food Items', 'Water Sanitation Hygiene')]
# Confidence in this prediction is: 42.48%
#
# Actual Place for this disaster is: ['Pakistan']
# Predicted Place for this disaster is: [('Pakistan',)]
# Confidence in this prediction is: 94.53%
#
# Actual Year for this disaster is: ['2006']
# Predicted Year for this disaster is: [('2006',)]
# Confidence in this prediction is: 89.26%
#
# Actual Month for this disaster is: ['May']
# Predicted Month for this disaster is: [('May',)]
# Confidence in this prediction is: 88.12%
#
# Actual Reason for this disaster is: ['Earthquake']
# Predicted Reason for this disaster is: [('Earthquake',)]
# Confidence in this prediction is: 91.37%
#
# Actual SDG for this disaster is: ['Industry Innovation and Infrastructure']
# Predicted SDG for this disaster is: [('Industry Innovation and Infrastructure',)]
# Confidence in this prediction is: 73.6%
#
# ------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 3.2. External Test (Twitter)

# %%
tweetDT = './Inputs/SEmHuS_Random_Humanitarian_Tweets.csv'
tweetDF = pd.read_csv(tweetDT)

# %%
print('++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++\n')
print(f'This is a data sub-set of 20 humanitarian tweets randomly picked from Twitter to test the model\n')
print('++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++\n')

for idx, row in enumerate(tweetDF.itertuples()):
    
    actText = str(row.tweet).lower()

    actText = preprocess.clean_text(actText)

    preText = ' '.join([w for w in str((actText + ' ') * padding_len).split()][:padding_len])

    preText = texts_tok.texts_to_sequences([preText])[0]
    preText = np.array([preText])
    preText = pad_sequences(preText, maxlen=padding_len, padding='post', truncating='post')

    outActor, outAgency, outSector, outPlace, outYear, outMonth, outReason, outGoal, outStat = model.predict(preText, verbose=0)

    maxActor = np.where(outActor>=np.sort(outActor[0])[-1], 1, 0)
    maxAgency = np.where(outAgency>=np.sort(outAgency[0])[-1], 1, 0)
    maxSector = np.where(outSector>=np.sort(outSector[0])[-1], 1, 0)
    maxPlace = np.where(outPlace>=np.sort(outPlace[0])[-1], 1, 0)
    maxYear = np.where(outYear>=np.sort(outYear[0])[-1], 1, 0)
    maxMonth = np.where(outMonth>=np.sort(outMonth[0])[-1], 1, 0)
    maxReason = np.where(outReason>=np.sort(outReason[0])[-1], 1, 0)
    maxGoal = np.where(outGoal>=np.sort(outGoal[0])[-1], 1, 0)

    preActor = labActor_tok.inverse_transform(maxActor)
    preAgency = labAgency_tok.inverse_transform(maxAgency)
    preSector = labSector_tok.inverse_transform(maxSector)
    prePlace = labPlace_tok.inverse_transform(maxPlace)
    preYear = labYear_tok.inverse_transform(maxYear)
    preMonth = labMonth_tok.inverse_transform(maxMonth)
    preReason = labReason_tok.inverse_transform(maxReason)
    preGoal = labGoal_tok.inverse_transform(maxGoal)

    print(f'The text used in this sample is: {actText} ......')
    print(f'Overall confidence in this prediction is: {round(outStat[0][0]*100, 2)}%\n')

    print(f'Predicted Actor for this question is:\t{preActor} | Confidence: {round(np.sort(outActor[0])[-1] * 100, 2)}%')
    print(f'Predicted Agency for this question is:\t{preAgency} | Confidence: {round(np.sort(outAgency[0])[-1] * 100, 2)}%')
    print(f'Predicted Sector for this question is:\t{preSector} | Confidence: {round(np.sort(outSector[0])[-1] * 100, 2)}%')
    print(f'Predicted Place for this question is:\t{prePlace} | Confidence: {round(np.sort(outPlace[0])[-1] * 100, 2)}%')
    print(f'Predicted Year for this question is:\t{preYear} | Confidence: {round(np.sort(outYear[0])[-1] * 100, 2)}%')
    print(f'Predicted Month for this question is:\t{preMonth} | Confidence: {round(np.sort(outMonth[0])[-1] * 100, 2)}%')
    print(f'Predicted Reason for this question is:\t{preReason} | Confidence: {round(np.sort(outReason[0])[-1] * 100, 2)}%')
    print(f'Predicted SDG for this question is:\t{preGoal} | Confidence: {round(np.sort(outGoal[0])[-1] * 100, 2)}%')
    print('------------------------------------------------------------------------------------------------\n')
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# This is a data sub-set of 20 humanitarian tweets randomly picked from Twitter to test the model
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# The text used in this sample is: improving refugee camp infrastructure responding growing humanitarian crisis students show skills knowledge work ethic build better lebanon . 🇱🇧 httpsanera . orgstorieson-the-job-training-students-communities-lebanon uniceflebanon education jobs relief lebanonprotests ......
# Overall confidence in this prediction is: 98.71%
#
# Predicted Actor for this question is:	[("SOS Children's Villages International",)] | Confidence: 64.99%
# Predicted Agency for this question is:	[('Non-governmental Organization',)] | Confidence: 91.83%
# Predicted Sector for this question is:	[('Education',)] | Confidence: 64.59%
# Predicted Place for this question is:	[('Lebanon',)] | Confidence: 80.77%
# Predicted Year for this question is:	[('2015',)] | Confidence: 67.3%
# Predicted Month for this question is:	[('July',)] | Confidence: 87.96%
# Predicted Reason for this question is:	[('Other',)] | Confidence: 26.8%
# Predicted SDG for this question is:	[('Industry Innovation and Infrastructure',)] | Confidence: 95.87%
# ------------------------------------------------------------------------------------------------
#
# The text used in this sample is: launch jrp rohingya humanitarian crisis 🇸🇪sweden announced contribution 32 million sek humanitarian allocation bangladesh . also contributes multiyear development funding crucial implementation jrp . ......
# Overall confidence in this prediction is: 98.3%
#
# Predicted Actor for this question is:	[('Government of Belgium',)] | Confidence: 26.07%
# Predicted Agency for this question is:	[('Government',)] | Confidence: 84.97%
# Predicted Sector for this question is:	[('Contributions',)] | Confidence: 65.95%
# Predicted Place for this question is:	[('Bangladesh',)] | Confidence: 92.35%
# Predicted Year for this question is:	[('2013',)] | Confidence: 86.21%
# Predicted Month for this question is:	[('May',)] | Confidence: 83.04%
# Predicted Reason for this question is:	[('Flood',)] | Confidence: 38.89%
# Predicted SDG for this question is:	[('Sustainable Cities and Communities',)] | Confidence: 85.3%
# ------------------------------------------------------------------------------------------------
#
# The text used in this sample is: street snacks sanitiser . heres afghan women fighting coronavirus kabul ......
# Overall confidence in this prediction is: 98.65%
#
# Predicted Actor for this question is:	[('European Commission Humanitarian Aid Office',)] | Confidence: 83.0%
# Predicted Agency for this question is:	[('Government',)] | Confidence: 93.67%
# Predicted Sector for this question is:	[('Food and Nutrition',)] | Confidence: 90.62%
# Predicted Place for this question is:	[('Afghanistan',)] | Confidence: 99.92%
# Predicted Year for this question is:	[('2002',)] | Confidence: 32.27%
# Predicted Month for this question is:	[('October',)] | Confidence: 51.88%
# Predicted Reason for this question is:	[('Drought',)] | Confidence: 91.91%
# Predicted SDG for this question is:	[('Sustainable Cities and Communities',)] | Confidence: 45.11%
# ------------------------------------------------------------------------------------------------
#
# The text used in this sample is: could covid-19 change humanitarianism forever disastermanagement crisis resilience disasterready emergencymanagement emergencypreparedness humanitarian covid19 ......
# Overall confidence in this prediction is: 99.11%
#
# Predicted Actor for this question is:	[('Australian Broadcasting Corporation',)] | Confidence: 52.73%
# Predicted Agency for this question is:	[('Media',)] | Confidence: 99.58%
# Predicted Sector for this question is:	[('Contributions',)] | Confidence: 34.1%
# Predicted Place for this question is:	[('Kenya',)] | Confidence: 48.99%
# Predicted Year for this question is:	[('2015',)] | Confidence: 77.67%
# Predicted Month for this question is:	[('August',)] | Confidence: 52.19%
# Predicted Reason for this question is:	[('Drought',)] | Confidence: 84.08%
# Predicted SDG for this question is:	[('Climate Action',)] | Confidence: 73.43%
# ------------------------------------------------------------------------------------------------
#
# The text used in this sample is: mobile humanitarian innovation programme supports stakeholders building inclusive digitally enabled humanitarian future mobile digital solutions provide services information choice affected crisis . httpsbit . ly3d76jvo ......
# Overall confidence in this prediction is: 98.98%
#
# Predicted Actor for this question is:	[('Open Society Foundations',)] | Confidence: 46.73%
# Predicted Agency for this question is:	[('Government',)] | Confidence: 80.54%
# Predicted Sector for this question is:	[('Health',)] | Confidence: 24.45%
# Predicted Place for this question is:	[('Liberia',)] | Confidence: 94.57%
# Predicted Year for this question is:	[('2014',)] | Confidence: 99.75%
# Predicted Month for this question is:	[('May',)] | Confidence: 47.92%
# Predicted Reason for this question is:	[('Epidemic',)] | Confidence: 74.59%
# Predicted SDG for this question is:	[('Clean Water and Sanitation',)] | Confidence: 73.96%
# ------------------------------------------------------------------------------------------------
#
# The text used in this sample is: translation voluntary acceptance refugees municipalities increase acceptance . rely enlightened self-interest humanitarian citizenship ground flanked federal govt assumption integration costs . turkey syrianrefugees crisis syrians ......
# Overall confidence in this prediction is: 98.89%
#
# Predicted Actor for this question is:	[('African Union',)] | Confidence: 51.11%
# Predicted Agency for this question is:	[('Government',)] | Confidence: 80.47%
# Predicted Sector for this question is:	[('Contributions',)] | Confidence: 43.22%
# Predicted Place for this question is:	[('World',)] | Confidence: 83.85%
# Predicted Year for this question is:	[('2015',)] | Confidence: 72.6%
# Predicted Month for this question is:	[('April',)] | Confidence: 64.66%
# Predicted Reason for this question is:	[('Epidemic',)] | Confidence: 34.53%
# Predicted SDG for this question is:	[('Industry Innovation and Infrastructure',)] | Confidence: 64.41%
# ------------------------------------------------------------------------------------------------
#
# The text used in this sample is: urgent prayer request friends syria ......
# Overall confidence in this prediction is: 98.54%
#
# Predicted Actor for this question is:	[('UN Secretary-General',)] | Confidence: 81.24%
# Predicted Agency for this question is:	[('Non-governmental Organization',)] | Confidence: 67.94%
# Predicted Sector for this question is:	[('Coordination',)] | Confidence: 19.07%
# Predicted Place for this question is:	[('Syrian Arab Republic',)] | Confidence: 87.16%
# Predicted Year for this question is:	[('2013',)] | Confidence: 96.62%
# Predicted Month for this question is:	[('February',)] | Confidence: 80.88%
# Predicted Reason for this question is:	[('Epidemic',)] | Confidence: 60.02%
# Predicted SDG for this question is:	[('Good Health and Well-being',)] | Confidence: 59.22%
# ------------------------------------------------------------------------------------------------
#
# The text used in this sample is: uq today government minister syrian conflict actions government taking prevent humanitarian crisis syria . ......
# Overall confidence in this prediction is: 98.81%
#
# Predicted Actor for this question is:	[('European Commission Humanitarian Aid Office',)] | Confidence: 91.75%
# Predicted Agency for this question is:	[('Government',)] | Confidence: 98.04%
# Predicted Sector for this question is:	[('Contributions',)] | Confidence: 64.22%
# Predicted Place for this question is:	[('Syrian Arab Republic',)] | Confidence: 100.0%
# Predicted Year for this question is:	[('2013',)] | Confidence: 98.33%
# Predicted Month for this question is:	[('January',)] | Confidence: 95.71%
# Predicted Reason for this question is:	[('Epidemic',)] | Confidence: 64.7%
# Predicted SDG for this question is:	[('Industry Innovation and Infrastructure',)] | Confidence: 22.5%
# ------------------------------------------------------------------------------------------------
#
# The text used in this sample is: concerned humanitarian outcome covid19 take weekly survey share insights min help us gain better understanding crisis evolves country operation ......
# Overall confidence in this prediction is: 98.84%
#
# Predicted Actor for this question is:	[('Government of Thailand',)] | Confidence: 39.38%
# Predicted Agency for this question is:	[('Academic and Research Institution',)] | Confidence: 42.34%
# Predicted Sector for this question is:	[('Recovery and Reconstruction',)] | Confidence: 96.89%
# Predicted Place for this question is:	[('World',)] | Confidence: 16.55%
# Predicted Year for this question is:	[('2016',)] | Confidence: 45.87%
# Predicted Month for this question is:	[('April',)] | Confidence: 62.59%
# Predicted Reason for this question is:	[('Tropical Cyclone',)] | Confidence: 38.72%
# Predicted SDG for this question is:	[('Peace Justice and Strong Institutions',)] | Confidence: 55.01%
# ------------------------------------------------------------------------------------------------
#
# The text used in this sample is: light ongoing crisis unrest mena nations redcross crescent movement partners disaster management functions playing strategic role responding humanitarian crisis ......
# Overall confidence in this prediction is: 98.76%
#
# Predicted Actor for this question is:	[('International Committee of the Red Cross',)] | Confidence: 99.91%
# Predicted Agency for this question is:	[('Red Cross/Red Crescent Movement',)] | Confidence: 81.62%
# Predicted Sector for this question is:	[('Water Sanitation Hygiene',)] | Confidence: 30.88%
# Predicted Place for this question is:	[('Niger',)] | Confidence: 23.98%
# Predicted Year for this question is:	[('2011',)] | Confidence: 33.14%
# Predicted Month for this question is:	[('May',)] | Confidence: 94.26%
# Predicted Reason for this question is:	[('Drought',)] | Confidence: 44.82%
# Predicted SDG for this question is:	[('Sustainable Cities and Communities',)] | Confidence: 81.08%
# ------------------------------------------------------------------------------------------------
#
# The text used in this sample is: launch 2020 joint response plan rohingya humanitarian crisis plan improve sustain multi-sector assistance including food water sanitation shelter healthcare education . ......
# Overall confidence in this prediction is: 98.8%
#
# Predicted Actor for this question is:	[('CARE',)] | Confidence: 56.54%
# Predicted Agency for this question is:	[('Non-governmental Organization',)] | Confidence: 68.04%
# Predicted Sector for this question is:	[('Water Sanitation Hygiene',)] | Confidence: 71.58%
# Predicted Place for this question is:	[('Pakistan',)] | Confidence: 43.5%
# Predicted Year for this question is:	[('2012',)] | Confidence: 41.83%
# Predicted Month for this question is:	[('May',)] | Confidence: 98.62%
# Predicted Reason for this question is:	[('Mud Slide',)] | Confidence: 67.31%
# Predicted SDG for this question is:	[('Industry Innovation and Infrastructure',)] | Confidence: 68.36%
# ------------------------------------------------------------------------------------------------
#
# The text used in this sample is: thread like extend heartfelt thanks southerncmr ambazonians sympathizers endured struggle liberation brutal subjugation lrc since intensified 2016 . remain committed total independence resistance forever . ......
# Overall confidence in this prediction is: 98.89%
#
# Predicted Actor for this question is:	[('Voice of America',)] | Confidence: 54.48%
# Predicted Agency for this question is:	[('Media',)] | Confidence: 80.24%
# Predicted Sector for this question is:	[('Health',)] | Confidence: 53.53%
# Predicted Place for this question is:	[('India',)] | Confidence: 98.26%
# Predicted Year for this question is:	[('2015',)] | Confidence: 83.73%
# Predicted Month for this question is:	[('December',)] | Confidence: 93.04%
# Predicted Reason for this question is:	[('Flash Flood',)] | Confidence: 46.03%
# Predicted SDG for this question is:	[('Peace Justice and Strong Institutions',)] | Confidence: 80.84%
# ------------------------------------------------------------------------------------------------
#
# The text used in this sample is: 100 millions indians jobless 40 million migrant workers stranded ......
# Overall confidence in this prediction is: 98.95%
#
# Predicted Actor for this question is:	[('Internal Displacement Monitoring Centre',)] | Confidence: 50.89%
# Predicted Agency for this question is:	[('Academic and Research Institution',)] | Confidence: 96.97%
# Predicted Sector for this question is:	[('Water Sanitation Hygiene',)] | Confidence: 60.55%
# Predicted Place for this question is:	[('Niger',)] | Confidence: 45.93%
# Predicted Year for this question is:	[('2013',)] | Confidence: 65.09%
# Predicted Month for this question is:	[('August',)] | Confidence: 57.65%
# Predicted Reason for this question is:	[('Flood',)] | Confidence: 95.68%
# Predicted SDG for this question is:	[('Reducing Inequality',)] | Confidence: 94.15%
# ------------------------------------------------------------------------------------------------
#
# The text used in this sample is: hongkong humanitarian crisis matter young old healthy handicapped way hkpolice screwed best scenario police insult verbally let go . shot pepper spray arrested normal hongkongers soshk ......
# Overall confidence in this prediction is: 98.85%
#
# Predicted Actor for this question is:	[('Voice of America',)] | Confidence: 53.61%
# Predicted Agency for this question is:	[('Media',)] | Confidence: 93.57%
# Predicted Sector for this question is:	[('Coordination',)] | Confidence: 28.12%
# Predicted Place for this question is:	[('Syrian Arab Republic',)] | Confidence: 26.94%
# Predicted Year for this question is:	[('2004',)] | Confidence: 58.82%
# Predicted Month for this question is:	[('September',)] | Confidence: 98.81%
# Predicted Reason for this question is:	[('Drought',)] | Confidence: 87.95%
# Predicted SDG for this question is:	[('Industry Innovation and Infrastructure',)] | Confidence: 99.45%
# ------------------------------------------------------------------------------------------------
#
# The text used in this sample is: lives thousands vulnerable people come halt due covid19 pandemic villages coxsbazar . humanitarian workers cannot stop . cash distribution going amidst crisis maintaining covidcompliance socialdistancing . thanks ......
# Overall confidence in this prediction is: 98.62%
#
# Predicted Actor for this question is:	[('World Health Organization',)] | Confidence: 62.61%
# Predicted Agency for this question is:	[('International Organization',)] | Confidence: 94.78%
# Predicted Sector for this question is:	[('Health',)] | Confidence: 84.55%
# Predicted Place for this question is:	[('Haiti',)] | Confidence: 78.03%
# Predicted Year for this question is:	[('2004',)] | Confidence: 55.45%
# Predicted Month for this question is:	[('June',)] | Confidence: 61.72%
# Predicted Reason for this question is:	[('Epidemic',)] | Confidence: 94.9%
# Predicted SDG for this question is:	[('Industry Innovation and Infrastructure',)] | Confidence: 33.16%
# ------------------------------------------------------------------------------------------------
#
# The text used in this sample is: power stop global pandemic evolving global humanitarian crisis . time dedicate energy challenges inspire others well ......
# Overall confidence in this prediction is: 98.7%
#
# Predicted Actor for this question is:	[('International Federation of Red Cross And Red Crescent Societies',)] | Confidence: 86.36%
# Predicted Agency for this question is:	[('International Organization',)] | Confidence: 44.03%
# Predicted Sector for this question is:	[('Health',)] | Confidence: 89.97%
# Predicted Place for this question is:	[('World',)] | Confidence: 97.05%
# Predicted Year for this question is:	[('2013',)] | Confidence: 66.17%
# Predicted Month for this question is:	[('November',)] | Confidence: 98.87%
# Predicted Reason for this question is:	[('Epidemic',)] | Confidence: 86.98%
# Predicted SDG for this question is:	[('Good Health and Well-being',)] | Confidence: 43.32%
# ------------------------------------------------------------------------------------------------
#
# The text used in this sample is: call attention humanitarian political crisis eritrea wake covid19 pandemic 95 distinguished eritrean scholars . 2020 manifesto eritrean scholars professionals diaspora erisat ......
# Overall confidence in this prediction is: 98.83%
#
# Predicted Actor for this question is:	[('Government of Canada',)] | Confidence: 58.93%
# Predicted Agency for this question is:	[('International Organization',)] | Confidence: 56.26%
# Predicted Sector for this question is:	[('Health',)] | Confidence: 90.17%
# Predicted Place for this question is:	[('Canada',)] | Confidence: 54.39%
# Predicted Year for this question is:	[('2005',)] | Confidence: 93.17%
# Predicted Month for this question is:	[('April',)] | Confidence: 96.3%
# Predicted Reason for this question is:	[('Epidemic',)] | Confidence: 28.81%
# Predicted SDG for this question is:	[('Good Health and Well-being',)] | Confidence: 95.75%
# ------------------------------------------------------------------------------------------------
#
# The text used in this sample is: government palestine quickly effectively responded outbreak covid19 using internationally nationally coordinated data-driven approach contain spread coronavirus within borders . ......
# Overall confidence in this prediction is: 98.74%
#
# Predicted Actor for this question is:	[('International Federation of Red Cross And Red Crescent Societies',)] | Confidence: 69.34%
# Predicted Agency for this question is:	[('Academic and Research Institution',)] | Confidence: 66.59%
# Predicted Sector for this question is:	[('Health',)] | Confidence: 83.62%
# Predicted Place for this question is:	[('Mexico',)] | Confidence: 50.48%
# Predicted Year for this question is:	[('2013',)] | Confidence: 70.39%
# Predicted Month for this question is:	[('April',)] | Confidence: 93.2%
# Predicted Reason for this question is:	[('Epidemic',)] | Confidence: 99.58%
# Predicted SDG for this question is:	[('Good Health and Well-being',)] | Confidence: 33.91%
# ------------------------------------------------------------------------------------------------
#
# The text used in this sample is: news rick sanchez yemen’s significant untapped oil resources . explains yemen’s oil potential might shed new light current conflict us role worst humanitarian crisis world . ......
# Overall confidence in this prediction is: 99.03%
#
# Predicted Actor for this question is:	[('GOAL',)] | Confidence: 33.84%
# Predicted Agency for this question is:	[('Non-governmental Organization',)] | Confidence: 93.21%
# Predicted Sector for this question is:	[('Water Sanitation Hygiene',)] | Confidence: 27.17%
# Predicted Place for this question is:	[('Nepal',)] | Confidence: 33.81%
# Predicted Year for this question is:	[('2010',)] | Confidence: 41.63%
# Predicted Month for this question is:	[('September',)] | Confidence: 99.48%
# Predicted Reason for this question is:	[('Earthquake',)] | Confidence: 78.87%
# Predicted SDG for this question is:	[('Life On Land',)] | Confidence: 60.53%
# ------------------------------------------------------------------------------------------------
#
# The text used in this sample is: communities clinics manage diabetes midst humanitarian crisis displacement violence malnutrition httpow . lykvop50y8i4m notjustdiet ......
# Overall confidence in this prediction is: 99.09%
#
# Predicted Actor for this question is:	[('International Medical Corps',)] | Confidence: 77.02%
# Predicted Agency for this question is:	[('Non-governmental Organization',)] | Confidence: 89.24%
# Predicted Sector for this question is:	[('Food and Nutrition',)] | Confidence: 31.54%
# Predicted Place for this question is:	[('Mali',)] | Confidence: 23.45%
# Predicted Year for this question is:	[('2013',)] | Confidence: 94.66%
# Predicted Month for this question is:	[('November',)] | Confidence: 54.48%
# Predicted Reason for this question is:	[('Flood',)] | Confidence: 40.77%
# Predicted SDG for this question is:	[('Industry Innovation and Infrastructure',)] | Confidence: 84.2%
# ------------------------------------------------------------------------------------------------
#
# The text used in this sample is: thats syria humanitarian fund supports ngo fouadi help thousands kids return school . colleague joumana explains humanitarians working harder ever even covid19 support need . downwards arrow ......
# Overall confidence in this prediction is: 98.43%
#
# Predicted Actor for this question is:	[('International Federation of Red Cross And Red Crescent Societies',)] | Confidence: 34.97%
# Predicted Agency for this question is:	[('International Organization',)] | Confidence: 63.52%
# Predicted Sector for this question is:	[('Education',)] | Confidence: 28.35%
# Predicted Place for this question is:	[('Syrian Arab Republic',)] | Confidence: 98.55%
# Predicted Year for this question is:	[('2011',)] | Confidence: 53.66%
# Predicted Month for this question is:	[('February',)] | Confidence: 61.72%
# Predicted Reason for this question is:	[('Drought',)] | Confidence: 40.5%
# Predicted SDG for this question is:	[('Industry Innovation and Infrastructure',)] | Confidence: 52.29%
# ------------------------------------------------------------------------------------------------
#
# The text used in this sample is: briefed donors today global appeal support worlds vulnerable countries response covid19 . must act decisively risk creating generations worth tragic exportable problems . httpsbit . ly30ulaqz ......
# Overall confidence in this prediction is: 98.66%
#
# Predicted Actor for this question is:	[('Government of Ireland',)] | Confidence: 38.35%
# Predicted Agency for this question is:	[('Non-governmental Organization',)] | Confidence: 82.96%
# Predicted Sector for this question is:	[('Coordination',)] | Confidence: 67.34%
# Predicted Place for this question is:	[('Benin',)] | Confidence: 63.35%
# Predicted Year for this question is:	[('2008',)] | Confidence: 43.05%
# Predicted Month for this question is:	[('October',)] | Confidence: 98.75%
# Predicted Reason for this question is:	[('Flood',)] | Confidence: 62.95%
# Predicted SDG for this question is:	[('Climate Action',)] | Confidence: 99.97%
# ------------------------------------------------------------------------------------------------
#
# The text used in this sample is: homs solid waste management projects cleaning streets support communities recover provide needed jobs workers . ......
# Overall confidence in this prediction is: 98.41%
#
# Predicted Actor for this question is:	[('Islamic Relief',)] | Confidence: 67.08%
# Predicted Agency for this question is:	[('Non-governmental Organization',)] | Confidence: 46.52%
# Predicted Sector for this question is:	[('Water Sanitation Hygiene',)] | Confidence: 49.52%
# Predicted Place for this question is:	[('Indonesia',)] | Confidence: 63.43%
# Predicted Year for this question is:	[('2014',)] | Confidence: 70.94%
# Predicted Month for this question is:	[('May',)] | Confidence: 48.89%
# Predicted Reason for this question is:	[('Epidemic',)] | Confidence: 46.78%
# Predicted SDG for this question is:	[('Industry Innovation and Infrastructure',)] | Confidence: 45.7%
# ------------------------------------------------------------------------------------------------
#
# The text used in this sample is: syria humanitarian fund 2019 annual report available . proud last year funding national ngos increased 11 per cent . hope year prioritizing localized needs-based response . ......
# Overall confidence in this prediction is: 98.83%
#
# Predicted Actor for this question is:	[('UN Office for the Coordination of Humanitarian Affairs',)] | Confidence: 34.78%
# Predicted Agency for this question is:	[('International Organization',)] | Confidence: 93.46%
# Predicted Sector for this question is:	[('Coordination',)] | Confidence: 52.55%
# Predicted Place for this question is:	[('Syrian Arab Republic',)] | Confidence: 99.12%
# Predicted Year for this question is:	[('2014',)] | Confidence: 97.48%
# Predicted Month for this question is:	[('September',)] | Confidence: 65.19%
# Predicted Reason for this question is:	[('Drought',)] | Confidence: 38.35%
# Predicted SDG for this question is:	[('Zero Hunger',)] | Confidence: 65.63%
# ------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 3.3. Competency Questions

# %%
questionFN = './Inputs/SEmHuS_Random_Competency_Question.csv'
questionDT = pd.read_csv(questionFN)

# %%
answerFN = './Inputs/SEmHuS_Random_Competency_Answer.csv'
answerDT = pd.DataFrame(columns=['actor', 'affiliation', 'sector', 'place', 'year', 'month', 'reason', 'SDG'])

# %%
print('++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++\n')
print(f'This is a data sub-set of 10 Competency Questions to test the model\n')
print('++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++\n')

for idx, row in enumerate(questionDT.itertuples()):
    
    actText = str(row.question).lower()

    actText = preprocess.clean_text(actText)

    preText = ' '.join([w for w in str((actText + ' ') * padding_len).split()][:padding_len])

    preText = texts_tok.texts_to_sequences([preText])[0]
    preText = np.array([preText])
    preText = pad_sequences(preText, maxlen=padding_len)

    outActor, outAgency, outSector, outPlace, outYear, outMonth, outReason, outGoal, outStat = model.predict(preText, verbose=0)

    maxActor = np.where(outActor>=np.sort(outActor[0])[-1], 1, 0)
    maxAgency = np.where(outAgency>=np.sort(outAgency[0])[-1], 1, 0)
    maxSector = np.where(outSector>=np.sort(outSector[0])[-1], 1, 0)
    maxPlace = np.where(outPlace>=np.sort(outPlace[0])[-1], 1, 0)
    maxYear = np.where(outYear>=np.sort(outYear[0])[-1], 1, 0)
    maxMonth = np.where(outMonth>=np.sort(outMonth[0])[-1], 1, 0)
    maxReason = np.where(outReason>=np.sort(outReason[0])[-1], 1, 0)
    maxGoal = np.where(outGoal>=np.sort(outGoal[0])[-1], 1, 0)

    preActor = labActor_tok.inverse_transform(maxActor)
    preAgency = labAgency_tok.inverse_transform(maxAgency)
    preSector = labSector_tok.inverse_transform(maxSector)
    prePlace = labPlace_tok.inverse_transform(maxPlace)
    preYear = labYear_tok.inverse_transform(maxYear)
    preMonth = labMonth_tok.inverse_transform(maxMonth)
    preReason = labReason_tok.inverse_transform(maxReason)
    preGoal = labGoal_tok.inverse_transform(maxGoal)

    print(f'The text used in this sample is: {actText} ......')
    print(f'Overall confidence in this prediction is: {round(outStat[0][0]*100, 2)}%\n')

    print(f'Predicted Actor is:\t{preActor} | Confidence: {round(np.sort(outActor[0])[-1] * 100, 2)}%')
    print(f'Predicted Agency is:\t{preAgency} | Confidence: {round(np.sort(outAgency[0])[-1] * 100, 2)}%')
    print(f'Predicted Sector is:\t{preSector} | Confidence: {round(np.sort(outSector[0])[-1] * 100, 2)}%')
    print(f'Predicted Place is:\t{prePlace} | Confidence: {round(np.sort(outPlace[0])[-1] * 100, 2)}%')
    print(f'Predicted Year is:\t{preYear} | Confidence: {round(np.sort(outYear[0])[-1] * 100, 2)}%')
    print(f'Predicted Month is:\t{preMonth} | Confidence: {round(np.sort(outMonth[0])[-1] * 100, 2)}%')
    print(f'Predicted Reason is:\t{preReason} | Confidence: {round(np.sort(outReason[0])[-1] * 100, 2)}%')
    print(f'Predicted SDG is:\t{preGoal} | Confidence: {round(np.sort(outGoal[0])[-1] * 100, 2)}%')
    print('\n------------------------------------------------------------------------------------------------\n')

    answerDT.loc[idx] = [preActor, preAgency, preSector, prePlace, preYear, preMonth, preReason, preGoal]

answerDT.to_csv(answerFN)
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# This is a data sub-set of 10 Competency Questions to test the model
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# The text used in this sample is: country earthquake 2007 ......
# Overall confidence in this prediction is: 98.99%
#
# Predicted Actor is:	[('International Organization for Migration',)] | Confidence: 99.38%
# Predicted Agency is:	[('International Organization',)] | Confidence: 98.27%
# Predicted Sector is:	[('Shelter and Non-Food Items',)] | Confidence: 46.85%
# Predicted Place is:	[('Uganda',)] | Confidence: 58.07%
# Predicted Year is:	[('2007',)] | Confidence: 96.38%
# Predicted Month is:	[('May',)] | Confidence: 59.82%
# Predicted Reason is:	[('Earthquake',)] | Confidence: 99.11%
# Predicted SDG is:	[('Sustainable Cities and Communities',)] | Confidence: 54.39%
#
# ------------------------------------------------------------------------------------------------
#
# The text used in this sample is: countries affected indian ocean tsunami 2005 ......
# Overall confidence in this prediction is: 99.16%
#
# Predicted Actor is:	[('American Red Cross',)] | Confidence: 85.98%
# Predicted Agency is:	[('Government',)] | Confidence: 68.79%
# Predicted Sector is:	[('Recovery and Reconstruction',)] | Confidence: 25.99%
# Predicted Place is:	[('Thailand',)] | Confidence: 36.77%
# Predicted Year is:	[('2005',)] | Confidence: 99.8%
# Predicted Month is:	[('August',)] | Confidence: 67.06%
# Predicted Reason is:	[('Tsunami',)] | Confidence: 88.16%
# Predicted SDG is:	[('Life On Land',)] | Confidence: 40.33%
#
# ------------------------------------------------------------------------------------------------
#
# The text used in this sample is: provides education children crises ......
# Overall confidence in this prediction is: 98.19%
#
# Predicted Actor is:	[("UN Children's Fund",)] | Confidence: 99.88%
# Predicted Agency is:	[('International Organization',)] | Confidence: 82.45%
# Predicted Sector is:	[('Education',)] | Confidence: 99.73%
# Predicted Place is:	[('Mali',)] | Confidence: 74.82%
# Predicted Year is:	[('2005',)] | Confidence: 70.48%
# Predicted Month is:	[('December',)] | Confidence: 49.2%
# Predicted Reason is:	[('Drought',)] | Confidence: 41.64%
# Predicted SDG is:	[('Climate Action',)] | Confidence: 58.01%
#
# ------------------------------------------------------------------------------------------------
#
# The text used in this sample is: reason msf intervene pakistan 2012 ......
# Overall confidence in this prediction is: 98.9%
#
# Predicted Actor is:	[('IRIN',)] | Confidence: 59.66%
# Predicted Agency is:	[('Media',)] | Confidence: 75.25%
# Predicted Sector is:	[('Health',)] | Confidence: 96.31%
# Predicted Place is:	[('Pakistan',)] | Confidence: 97.59%
# Predicted Year is:	[('2013',)] | Confidence: 78.75%
# Predicted Month is:	[('April',)] | Confidence: 70.58%
# Predicted Reason is:	[('Flash Flood',)] | Confidence: 36.54%
# Predicted SDG is:	[('Sustainable Cities and Communities',)] | Confidence: 55.85%
#
# ------------------------------------------------------------------------------------------------
#
# The text used in this sample is: organisation charge food security ......
# Overall confidence in this prediction is: 99.2%
#
# Predicted Actor is:	[('Agence France-Presse',)] | Confidence: 59.48%
# Predicted Agency is:	[('Media',)] | Confidence: 98.88%
# Predicted Sector is:	[('Food and Nutrition',)] | Confidence: 98.71%
# Predicted Place is:	[('Haiti',)] | Confidence: 70.84%
# Predicted Year is:	[('2014',)] | Confidence: 85.56%
# Predicted Month is:	[('September',)] | Confidence: 95.46%
# Predicted Reason is:	[('Epidemic',)] | Confidence: 70.89%
# Predicted SDG is:	[('Zero Hunger',)] | Confidence: 96.25%
#
# ------------------------------------------------------------------------------------------------
#
# The text used in this sample is: reasons humanitarian crises africa ......
# Overall confidence in this prediction is: 98.43%
#
# Predicted Actor is:	[('Guardian',)] | Confidence: 51.28%
# Predicted Agency is:	[('Media',)] | Confidence: 54.35%
# Predicted Sector is:	[('Food and Nutrition',)] | Confidence: 34.54%
# Predicted Place is:	[('Mali',)] | Confidence: 37.54%
# Predicted Year is:	[('2015',)] | Confidence: 94.99%
# Predicted Month is:	[('September',)] | Confidence: 91.15%
# Predicted Reason is:	[('Drought',)] | Confidence: 66.63%
# Predicted SDG is:	[('Good Health and Well-being',)] | Confidence: 97.13%
#
# ------------------------------------------------------------------------------------------------
#
# The text used in this sample is: ebola epidemic took place ......
# Overall confidence in this prediction is: 98.79%
#
# Predicted Actor is:	[('European Commission Humanitarian Aid Office',)] | Confidence: 37.05%
# Predicted Agency is:	[('Government',)] | Confidence: 90.18%
# Predicted Sector is:	[('Contributions',)] | Confidence: 55.78%
# Predicted Place is:	[('Sierra Leone',)] | Confidence: 52.98%
# Predicted Year is:	[('2014',)] | Confidence: 64.05%
# Predicted Month is:	[('October',)] | Confidence: 77.76%
# Predicted Reason is:	[('Epidemic',)] | Confidence: 99.93%
# Predicted SDG is:	[('Good Health and Well-being',)] | Confidence: 95.66%
#
# ------------------------------------------------------------------------------------------------
#
# The text used in this sample is: year unhcr provided shelter refugees iraq ......
# Overall confidence in this prediction is: 98.81%
#
# Predicted Actor is:	[('UN High Commissioner for Refugees',)] | Confidence: 94.92%
# Predicted Agency is:	[('International Organization',)] | Confidence: 90.74%
# Predicted Sector is:	[('Shelter and Non-Food Items',)] | Confidence: 75.07%
# Predicted Place is:	[('Iraq',)] | Confidence: 77.02%
# Predicted Year is:	[('2014',)] | Confidence: 78.71%
# Predicted Month is:	[('September',)] | Confidence: 61.15%
# Predicted Reason is:	[('Drought',)] | Confidence: 45.23%
# Predicted SDG is:	[('Industry Innovation and Infrastructure',)] | Confidence: 84.48%
#
# ------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 3.4. Random Questions

# %%
from sklearn.metrics import accuracy_score

# %%
print('++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++')
print(f'Free text query to try the model and assess the quality of the answers')
print('++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++\n')

# num_answer = 5

actText = 'Pacific Tropical Cyclone unicef'

padText = ' '.join([w for w in str((actText + ' ') * padding_len).split()][:padding_len])

padText = preprocess.clean_text(padText)

preText = texts_tok.texts_to_sequences([padText])[0]
preText = np.array([preText])
preText = pad_sequences(preText, maxlen=padding_len, padding='post', truncating='post')

outActor, outAgency, outSector, outPlace, outYear, outMonth, outReason, outGoal, outStat = model.predict(preText, verbose=0)

maxActor = np.where(outActor>=np.sort(outActor[0])[-1], 1, 0)
maxAgency = np.where(outAgency>=np.sort(outAgency[0])[-1], 1, 0)
maxSector = np.where(outSector>=np.sort(outSector[0])[-1], 1, 0)
maxPlace = np.where(outPlace>=np.sort(outPlace[0])[-1], 1, 0)
maxYear = np.where(outYear>=np.sort(outYear[0])[-1], 1, 0)
maxMonth = np.where(outMonth>=np.sort(outMonth[0])[-1], 1, 0)
maxReason = np.where(outReason>=np.sort(outReason[0])[-1], 1, 0)
maxGoal = np.where(outGoal>=np.sort(outGoal[0])[-1], 1, 0)

preActor = labActor_tok.inverse_transform(maxActor)
preAgency = labAgency_tok.inverse_transform(maxAgency)
preSector = labSector_tok.inverse_transform(maxSector)
prePlace = labPlace_tok.inverse_transform(maxPlace)
preYear = labYear_tok.inverse_transform(maxYear)
preMonth = labMonth_tok.inverse_transform(maxMonth)
preReason = labReason_tok.inverse_transform(maxReason)
preGoal = labGoal_tok.inverse_transform(maxGoal)

print(f'The text used in this example is: {actText} ......')
print(f'Overall confidence in this prediction is: {round(outStat[0][0]*100, 2)}%\n')

print(f'Predicted Actor is:\t{preActor} | Confidence: {round(np.sort(outActor[0])[-1] * 100, 2)}%')
print(f'Predicted Agency is:\t{preAgency} | Confidence: {round(np.sort(outAgency[0])[-1] * 100, 2)}%')
print(f'Predicted Sector is:\t{preSector} | Confidence: {round(np.sort(outSector[0])[-1] * 100, 2)}%')
print(f'Predicted Place is:\t{prePlace} | Confidence: {round(np.sort(outPlace[0])[-1] * 100, 2)}%')
print(f'Predicted Year is:\t{preYear} | Confidence: {round(np.sort(outYear[0])[-1] * 100, 2)}%')
print(f'Predicted Month is:\t{preMonth} | Confidence: {round(np.sort(outMonth[0])[-1] * 100, 2)}%')
print(f'Predicted Reason is:\t{preReason} | Confidence: {round(np.sort(outReason[0])[-1] * 100, 2)}%')
print(f'Predicted SDG is:\t{preGoal} | Confidence: {round(np.sort(outGoal[0])[-1] * 100, 2)}%')
print('\n--------------------------------------------------------------------------------------------------\n')
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Free text query to try the model and assess the quality of the answers
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# The text used in this example is: Pacific Tropical Cyclone unicef ......
# Overall confidence in this prediction is: 99.07%
#
# Predicted Actor is:	[("UN Children's Fund",)] | Confidence: 94.83%
# Predicted Agency is:	[('International Organization',)] | Confidence: 99.79%
# Predicted Sector is:	[('Education',)] | Confidence: 32.02%
# Predicted Place is:	[('Samoa',)] | Confidence: 31.53%
# Predicted Year is:	[('2007',)] | Confidence: 31.11%
# Predicted Month is:	[('December',)] | Confidence: 38.77%
# Predicted Reason is:	[('Tropical Cyclone',)] | Confidence: 99.74%
# Predicted SDG is:	[('Sustainable Cities and Communities',)] | Confidence: 62.7%
#
# --------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 3.5. Draw Answers

# %%
from sklearn.manifold import TSNE
import seaborn
from  matplotlib import pyplot
seaborn.set(context='notebook', style='ticks', palette='deep', font='sans-serif', font_scale=1.4, color_codes=False, rc=None)

# %%
tsne = TSNE(n_components=2, random_state=0)

# %%
randDF = normDF

# %%
ansVector = []

ansActor, ansAgency, ansSector, ansPlace, ansYear, ansMonth, ansReason, ansGoal = [], [], [], [], [], [], [], []
conActor, conAgency, conSector, conPlace, conYear, conMonth, conReason, conGoal = [], [], [], [], [], [], [], []

for idx, row in enumerate(randDF.itertuples()):
    
    actText = str(row.text)
    actActor = eval(row.source_name)
    actAgency = eval(row.source_type)
    actSector = eval(row.theme)
    actPlace = eval(row.country_name)
    actYear = eval(row.year_created)
    actMonth = eval(row.month_created)
    actReason = eval(row.disaster_type)
    actGoal = eval(row.development_goal)

    preText = texts_tok.texts_to_sequences([actText])[0]
    preText = np.array([preText])
    preText = pad_sequences(preText, maxlen=padding_len)

    outActor, outAgency, outSector, outPlace, outYear, outMonth, outReason, outGoal, outStat = model.predict(preText, verbose=0)

    maxActor = np.where(outActor>=np.sort(outActor[0])[-len(set(actActor))], 1, 0)
    maxAgency = np.where(outAgency>=np.sort(outAgency[0])[-len(set(actAgency))], 1, 0)
    maxSector = np.where(outSector>=np.sort(outSector[0])[-len(set(actSector))], 1, 0)
    maxPlace = np.where(outPlace>=np.sort(outPlace[0])[-len(set(actPlace))], 1, 0)
    maxYear = np.where(outYear>=np.sort(outYear[0])[-len(set(actYear))], 1, 0)
    maxMonth = np.where(outMonth>=np.sort(outMonth[0])[-len(set(actMonth))], 1, 0)
    maxReason = np.where(outReason>=np.sort(outReason[0])[-len(set(actReason))], 1, 0)
    maxGoal = np.where(outGoal>=np.sort(outGoal[0])[-len(set(actGoal))], 1, 0)

    preActor = labActor_tok.inverse_transform(maxActor)
    preAgency = labAgency_tok.inverse_transform(maxAgency)
    preSector = labSector_tok.inverse_transform(maxSector)
    prePlace = labPlace_tok.inverse_transform(maxPlace)
    preYear = labYear_tok.inverse_transform(maxYear)
    preMonth = labMonth_tok.inverse_transform(maxMonth)
    preReason = labReason_tok.inverse_transform(maxReason)
    preGoal = labGoal_tok.inverse_transform(maxGoal)

    outVector = [outActor[0], outAgency[0], outSector[0], outPlace[0], outYear[0], outMonth[0], outReason[0], outGoal[0]]
    outVector = itertools.chain(*outVector)
    outVector = list(outVector)
    
    ansVector.append(outVector)

    ansActor.append(preActor[0][0])
    ansAgency.append(preAgency[0][0])
    ansSector.append(preSector[0][0])
    ansPlace.append(prePlace[0][0])
    ansYear.append(preYear[0][0])
    ansMonth.append(preMonth[0][0])
    ansReason.append(preReason[0][0])
    ansGoal.append(preGoal[0][0])

    conActor.append(np.sort(outActor[0])[-1])
    conAgency.append(np.sort(outAgency[0])[-1])
    conSector.append(np.sort(outSector[0])[-1])
    conPlace.append(np.sort(outPlace[0])[-1])
    conYear.append(np.sort(outYear[0])[-1])
    conMonth.append(np.sort(outMonth[0])[-1])
    conReason.append(np.sort(outReason[0])[-1])
    conGoal.append(np.sort(outGoal[0])[-1])

# %%
from keras import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
arr_shape = np.shape(arr)[-1]

# %%
arr = np.asarray(ansVector, dtype=np.float32)

# %%
def autoencoder(data):
    m = Sequential()
    m.add(Dense(512,  activation='tanh', input_shape=(arr_shape,)))
    m.add(Dense(128,  activation='sigmoid'))
    m.add(Dense(300,    activation='linear', name="bottleneck"))
    m.add(Dense(128,  activation='elu'))
    m.add(Dense(512,  activation='elu'))
    m.add(Dense(arr_shape,  activation='sigmoid'))

    m.compile(loss='mean_squared_error', optimizer = Adam())

    history = m.fit(data, data, batch_size=128, epochs=5, verbose=1)

    encoder = Model(m.input, m.get_layer('bottleneck').output)
    Zenc = encoder.predict(data)
    Renc = m.predict(data)
    return Zenc

# %%
res = autoencoder(arr)
# Out:
# Epoch 1/5
# 5280/5280 [==============================] - 1s 266us/step - loss: 0.0278
# Epoch 2/5
# 5280/5280 [==============================] - 1s 165us/step - loss: 0.0033
# Epoch 3/5
# 5280/5280 [==============================] - 1s 164us/step - loss: 0.0033
# Epoch 4/5
# 5280/5280 [==============================] - 1s 163us/step - loss: 0.0033
# Epoch 5/5
# 5280/5280 [==============================] - 1s 166us/step - loss: 0.0033

# %%
tsne = TSNE(n_components=2, random_state=0)
reduced_vector = tsne.fit_transform(arr)
X_dim = reduced_vector[:,0]
Y_dim = reduced_vector[:,1]

# %%
answer_df = pd.DataFrame({'Actor':ansActor,
                        'Agency':ansAgency,
                        'Sector':ansSector,
                        'Place':ansPlace,
                        'Year':ansYear,
                        'Month':ansMonth,
                        'Reason':ansReason,
                        'SDG':ansGoal,
                        'Vector':res.tolist(),
                        'X':X_dim,
                        'Y':Y_dim})

# %% [markdown]
# ### 3.5.0. Actor Plot

# %%
_actor = labActor_tok.classes_.tolist()

fg = seaborn.FacetGrid(data=answer_df, hue='Actor', hue_order=_actor, aspect=1.61, height=10)
fg.map(pyplot.scatter, 'X', 'Y')

# %% [markdown]
# ### 3.5.1. Agency Plot

# %%
_agency = labAgency_tok.classes_.tolist()

fg = seaborn.FacetGrid(data=answer_df, hue='Agency', hue_order=_agency, aspect=1.61, height=10)
fg.map(pyplot.scatter, 'X', 'Y').add_legend()

# %% [markdown]
# ### 3.5.2. Sector Plot

# %%
_sector = labSector_tok.classes_.tolist()

fg = seaborn.FacetGrid(data=answer_df, hue='Sector', hue_order=_sector, aspect=1.61, height=10)
fg.map(pyplot.scatter, 'X', 'Y').add_legend()

# %% [markdown]
# ### 3.5.3. Year Plot

# %%
_year = labYear_tok.classes_.tolist()

fg = seaborn.FacetGrid(data=answer_df, hue='Year', hue_order=_year, aspect=1.61, height=10)
fg.map(pyplot.scatter, 'X', 'Y').add_legend()

# %% [markdown]
# ### 3.5.4. Month Plot

# %%
_month = labMonth_tok.classes_.tolist()

fg = seaborn.FacetGrid(data=answer_df, hue='Month', hue_order=_month, aspect=1.61, height=10)
fg.map(pyplot.scatter, 'X', 'Y').add_legend()

# %% [markdown]
# ### 3.5.X Reasons Plot

# %%
_reason = labReason_tok.classes_.tolist()

fg = seaborn.FacetGrid(data=answer_df, hue='Reason', hue_order=_reason, aspect=1.61, height=10)
fg.map(pyplot.scatter, 'X', 'Y').add_legend()

# %% [markdown]
# ### 3.5.X SDG Plot

# %%
_goal = labGoal_tok.classes_.tolist()

fg = seaborn.FacetGrid(data=answer_df, hue='SDG', hue_order=_goal, aspect=1.61, height=10)
fg.map(pyplot.scatter, 'X', 'Y').add_legend()

# %% [markdown]
# # 4. Knowledge Extraction

# %%
num_word = 5

# %% [markdown]
# ## 4.1. Paraphrasing

# %%
from scipy.spatial import distance

# %%
for i in dictEmbed:
    print(i)
    break
# Out:
# people

# %%
def nearest_word(word):
    vec1 = dictEmbed[word]
    dist = []
    for word2, vec2 in dictEmbed.items():
        dist.append((np.linalg.norm(vec1 - vec2), word2))
    dist.sort()
    dist = dist[:num_word]
    return dist

def nearest_vector(vector):
    vec1 = vector
    dist = []
    for word2, vec2 in dictEmbed.items():
        dist.append((np.linalg.norm(vec1 - vec2), word2))
    dist.sort()
    dist = dist[:num_word]
    return dist

# %%
from scipy import spatial

# %%
find_nearest = 'development -undp +wfp'

ntr_word = []
pos_word = []
neg_word = []

key_words = find_nearest.lower()
key_words = key_words.split(' ')

for word in key_words:
    exact_word = word[1:]
    if word.startswith('+'):
        pos_word.append(dictEmbed[exact_word])
    elif word.startswith('-'):
        neg_word.append(dictEmbed[exact_word])
    else:
        ntr_word.append(dictEmbed[word])

pos_vec = np.sum(pos_word, axis=0)
neg_vec = np.sum(neg_word, axis=0)
ntr_vec = np.sum(ntr_word, axis=0)

sub_vect = np.add(ntr_vec, np.subtract(pos_vec, neg_vec))

result = []

for key, val in dictEmbed.items():
    obj_name = key
    obj_vect = val
    #print(obj_vect)
    
    tmp_dist = np.linalg.norm(sub_vect - obj_vect)

    result.append((tmp_dist, obj_name))

result.sort()
result = result[0:10]

for d, r in result:
    print(f'{r} ({round(d, 4)})')
# Out:
# food (3.95)
# development (4.1486)
# emergency (4.2584)
# children (4.3085)
# nutrition (4.3287)
# humanitarian (4.3358)
# supplies (4.3369)
# government (4.3412)
# rice (4.3646)
# areas (4.3652)
